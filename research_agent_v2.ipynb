# %% [markdown]
# # Create a Research Agent

# %% [markdown]
# This is a concept agent that is inspired by my process of researching on a subject. <br>
# I also took some inspiration from BabyAGI (without tools) implementation

# %%
from dotenv import load_dotenv

load_dotenv("./.env")
import uuid
import os
from langchain.chat_models import ChatOpenAI
from langchain.embeddings import OpenAIEmbeddings
from langchain.prompts import PromptTemplate
from yachalk import chalk

# %%
text_embedding_model = "text-embedding-ada-002"
embeddings = OpenAIEmbeddings(model=text_embedding_model)

# %% [markdown]
# ## Set up the vector store

# %%
use_localdb = False

SUPABASE_PASSWORD = os.environ["SUPABASE_PASSWORD"]
SUPABASE_DBUSER = os.environ["SUPABASE_DBUSER"]
SUPABASE_DATABASE = os.environ["SUPABASE_DATABASE"]
supabasedb_string = f"postgresql://{SUPABASE_DBUSER}:{SUPABASE_PASSWORD}@db.doxggeyqopdnxfhseufq.supabase.co:5432/{SUPABASE_DATABASE}"

PGVECTOR_USER = os.environ["PGVECTOR_USER"]
PGVECTOR_PASSWORD = os.environ["PGVECTOR_PASSWORD"]
PGVECTOR_DATABASE = os.environ["PGVECTOR_DATABASE"]
localdb_string = f"postgresql://{PGVECTOR_USER}:{PGVECTOR_PASSWORD}@localhost:5432/{PGVECTOR_DATABASE}"

connection_string = localdb_string if use_localdb else supabasedb_string

# %%
## Law store
from langchain.vectorstores import PGVector

law_compilation_store = PGVector(
    collection_name="law_compilation",
    connection_string=connection_string,
    embedding_function=embeddings,
)

## Mahabharata Store
mahabharata_store = PGVector(
    collection_name="mahabharat_combined_text",
    connection_string=connection_string,
    embedding_function=embeddings,
)

# %% [markdown]
# ### Supabase vector store for storing runs
#
# The supabase client here is not used as a vector store.
# I am only using it to save the runs data.
# You can remove it if you dont need it.

# %%
from supabase.client import Client, create_client
from langchain.vectorstores import SupabaseVectorStore

supabase_url = os.environ.get("SUPABASE_URL")
supabase_key = os.environ.get("SUPABASE_SERVICE_KEY")
supabase: Client = create_client(supabase_url, supabase_key)

runs_store = SupabaseVectorStore(
    embedding=embeddings, client=supabase, table_name="runs", query_name="match_runs"
)

# ## Testing store
# run_id = str(uuid.uuid4())
# runs_store.add_texts(texts=["testing the store"], metadatas=[{"key": "value"}], ids=[run_id])
# matched_docs = runs_store.similarity_search_with_relevance_scores("testing store", 1)
# matched_docs

# %% [markdown]
# ### Import Chains

# %% [markdown]
# #### Question creator
#
# Generate new questions based on
#
# -   `question` - Original question. This is important so that the pertinence to the original question is always maintained. Or else the context can diverge quickly into impertinent results.
# -   `unanswered_questions`: So that the new questions do not overlap with the old ones.
# -   `context`: The answer to the last question.
# -   `num_questions`: Configurable hyper parameter.
# -   `start_id`: This is passed so that the ids of the newly generated question do overlap with the current list.
#
# ---
#
# #### Most pertinent Question chain
#
# Pick the most pertinent question out of the given list of questions <br>
# I am not using any additional context other than the `original_question` for decising the pertinence.
#
# ---
#
# #### Retrieval QA
#
# This chain is used to answer the intermediate questions. The idea is to generate succinct answers which can be used as notes to finally answer the original question
#
# ---
#
# #### Result Analyser
#
# Not using this right now. I am not able to get this piece working well. So currently I will just run the agent for a fixed number of iterations and then compile the answer.

# %%
## Import all the chains.
from chains_v2.create_questions import QuestionCreationChain
from chains_v2.most_pertinent_question import MostPertinentQuestion
from chains_v2.retrieval_qa import retrieval_qa
from chains_v2.research_compiler import research_compiler
from chains_v2.question_atomizer import QuestionAtomizer

## Model with parameters
gpt3t = "gpt-3.5-turbo"


def language_model(
    model_name: str = gpt3t, temperature: float = 0, verbose: bool = False
):
    llm = ChatOpenAI(model_name=model_name, temperature=temperature, verbose=verbose)
    return llm

# %% [markdown]
# ### Importing Question helpers

# %%
from helpers.response_helpers import result2QuestionsList
from helpers.response_helpers import qStr2Dict
from helpers.questions_helper import getAnsweredQuestions
from helpers.questions_helper import getUnansweredQuestions
from helpers.questions_helper import getSubQuestions
from helpers.questions_helper import getHopQuestions
from helpers.questions_helper import getLastQuestionId
from helpers.questions_helper import markAnswered
from helpers.questions_helper import getQuestionById

# %% [markdown]
# # The Research Agent

# %% [markdown]
# Question Data Schema
#
# ```
#   Question: {
#     id: int,
#     question: string,
#     type: 'subquestion' | 'hops',
#     status: 'answered' | 'unanswered',
#     answer: string,
#     documents: []
#   }
# ```

# %%
run_id = str(uuid.uuid4())
scratchpad = {
    "original_question": "Exploain section 8 of the companies act?",
    "questions": [],  # list of type Question
}
verbose = False
max_iterations = 3
current_iteration = 0
num_atomistic_questions = 2
num_questions_per_iteration = 4
question_atomizer_temperature = 0
question_creation_temperature = 0.2
question_prioritisation_temperature = 0
qa_temperature = 0
analyser_temperature = 0
intermediate_answers_length = 200
answer_length = 500
store = law_compilation_store

## ---- The researcher ----- ##

## Step 0. Prepare the initial set of questions
question_atomizer = QuestionAtomizer.from_llm(
    llm=language_model(temperature=question_atomizer_temperature), verbose=verbose
)

atomized_questions_response = question_atomizer.run(
    question=scratchpad["original_question"],
    num_questions=num_atomistic_questions,
)

scratchpad["questions"] += result2QuestionsList(
    question_response=atomized_questions_response,
    type="subquestion",
    status="unanswered",
)

for q in scratchpad["questions"]:
    q["answer"], q["documents"] = retrieval_qa(
        llm=language_model(temperature=qa_temperature, verbose=verbose),
        retriever=store.as_retriever(
            search_type="mmr", search_kwargs={"k": 5, "fetch_k": 10}
        ),
        question=q["question"],
        answer_length=intermediate_answers_length,
        verbose=verbose,
    )
    q["status"] = "answered"
    print(chalk.magenta.bold(f"** Sub Question **\n{q['question']}\n{q['answer']}\n"))

current_context = "".join(
    f"\n{q['id']}. {q['question']}\n{q['answer']}\n" for q in scratchpad["questions"]
)


verbose = False
while True:
    current_iteration += 1
    print(
        chalk.bg_yellow_bright.black.bold(f"\n   Iteration - {current_iteration}  ▷▶  \n")
    )

    # STEP 1: create questions
    start_id = getLastQuestionId(scratchpad["questions"]) + 1
    question_creation_chain = QuestionCreationChain.from_llm(
        language_model(temperature=question_creation_temperature), verbose=verbose
    )
    questions_response = question_creation_chain.run(
        question=scratchpad["original_question"],
        context=current_context,
        previous_questions=[
            "".join(f"\n{q['question']}") for q in scratchpad["questions"]
        ],
        num_questions=num_questions_per_iteration,
        start_id=start_id,
    )
    scratchpad["questions"] += result2QuestionsList(
        question_response=questions_response,
        type="hop",
        status="unanswered",
    )

    # STEP 2: Choose question for current iteration
    unanswered = getUnansweredQuestions(scratchpad["questions"])
    unanswered_questions_prompt = (
        "[" + "".join([f"\n{q['id']}. {q['question']}" for q in unanswered]) + "]"
    )
    print(
        chalk.cyan_bright("** Unanswered Questions **"),
        chalk.cyan("".join([f"\n'{q['id']}. {q['question']}'" for q in unanswered])),
    )
    most_pertinent_question = MostPertinentQuestion.from_llm(
        language_model(temperature=question_creation_temperature), verbose=verbose
    )
    response = most_pertinent_question.run(
        original_question=scratchpad["original_question"],
        unanswered_questions=unanswered_questions_prompt,
    )

    current_question_dict = qStr2Dict(question=response)
    current_question_id = current_question_dict["id"]

    current_question = getQuestionById(scratchpad["questions"], current_question_id)

    print(
        chalk.magenta.bold("** 🤔 Next Questions I must ask: **\n"),
        chalk.magenta(current_question_id),
        chalk.magenta(current_question["question"]),
    )

    # STEP 3: Answer the question
    current_question["answer"], current_question["documents"] = retrieval_qa(
        llm=language_model(temperature=qa_temperature, verbose=verbose),
        retriever=store.as_retriever(
            search_type="mmr", search_kwargs={"k": 5, "fetch_k": 10}
        ),
        question=current_question["question"],
        answer_length=intermediate_answers_length,
        verbose=verbose,
    )
    markAnswered(scratchpad["questions"], current_question_id)

    print(
        chalk.yellow_bright.bold("** Answer **\n"),
        chalk.yellow_bright(current_question["answer"]),
    )

    current_context = current_question["answer"]

    if current_iteration > max_iterations:
        print(
            chalk.bg_yellow_bright.black.bold(
                "\n ✔✔  Max Iterations Reached. Compiling the results ...    \n"
            )
        )
        break


## STEP 4: Compile the research
answered_questions = getAnsweredQuestions(scratchpad["questions"])
answered_questions_prompt = (
    "["
    + "".join(
        [
            f"{{ Question: {q['question']}, Answer: {q['answer']} }}"
            for q in answered_questions
        ]
    )
    + "]"
)
result = research_compiler(
    llm=language_model(temperature=qa_temperature, verbose=verbose),
    question=scratchpad["original_question"],
    notes=answered_questions_prompt,
    answer_length=answer_length,
    verbose=verbose,
)

print(chalk.italic.white_bright((result["text"])))

# current_question = response
## Collect initial document with semantic search.
# Out:
# ** Sub Question **
# What is section 8 of the Companies Act?
# Section 8 of the Companies Act, 2013 deals with the formulation of companies with charitable objects. It states that if a person or an association of persons intends to register as a limited company under this Act and has the objective of promoting commerce, art, science, sports, education, research, social welfare, religion, charity, protection of environment, or any other similar object, they can do so with the satisfaction of the Central Government. This section allows for the registration of companies that have charitable or socially beneficial objectives.
#
# ** Sub Question **
# What does section 8 of the Companies Act explain?
# Section 8 of the Companies Act explains the formation of companies with charitable objects or purposes. It provides guidelines and regulations for companies that are established for charitable or non-profit purposes. This section outlines the requirements and procedures for incorporating such companies and the effect of registration. It also covers the alteration of the memorandum and articles of association of these companies. Overall, section 8 of the Companies Act focuses on the specific rules and provisions applicable to companies with charitable objectives.
#
#
#    Iteration - 1  ▷▶
#
# ** Unanswered Questions **
# '3. What are the specific objectives that a company can have in order to register under section 8 of the Companies Act?'
# '4. What is the role of the Central Government in the registration process of companies under section 8 of the Companies Act?'
# '5. How does section 8 of the Companies Act address the alteration of the memorandum and articles of association for companies with charitable objectives?'
# '6. Are there any limitations or restrictions on the activities of companies registered under section 8 of the Companies Act?'
# ** 🤔 Next Questions I must ask: **
#  3 What are the specific objectives that a company can have in order to register under section 8 of the Companies Act?
# ** Answer **
#  The specific objectives that a company can have in order to register under section 8 of the Companies Act are the promotion of commerce, art, science, sports, education, research, social welfare, religion, charity, protection of environment, or any other similar object. These objectives should be clearly stated in the company's objects clause when applying for registration. Additionally, the liability of the members of the company should be limited, and they should undertake to contribute to the assets of the company in the event of its winding up for payment of debts and liabilities. The company should also ensure that secured creditors have given their consent or no objection to the company's registration, publish advertisements seeking objections, and file an affidavit from all members or partners stating that necessary documents will be submitted for the dissolution of the company as a partnership firm.
#
#    Iteration - 2  ▷▶
#
# ** Unanswered Questions **
# '4. What is the role of the Central Government in the registration process of companies under section 8 of the Companies Act?'
# '5. How does section 8 of the Companies Act address the alteration of the memorandum and articles of association for companies with charitable objectives?'
# '6. Are there any limitations or restrictions on the activities of companies registered under section 8 of the Companies Act?'
# '7. What are the specific requirements for a company to register under section 8 of the Companies Act?'
# '8. How does the liability of the members of a company registered under section 8 of the Companies Act differ from other companies?'
# '9. What steps should a company registered under section 8 of the Companies Act take to ensure the consent of secured creditors during the registration process?'
# '10. What documents need to be submitted by the members or partners of a company registered under section 8 of the Companies Act for the dissolution of the company as a partnership firm?'
# ** 🤔 Next Questions I must ask: **
#  5 How does section 8 of the Companies Act address the alteration of the memorandum and articles of association for companies with charitable objectives?
# ** Answer **
#  Section 8 of the Companies Act addresses the formation of companies with charitable objectives. It states that if a person or association of persons proposed to be registered as a limited company has charitable objectives, such as the promotion of commerce, art, science, sports, education, research, social welfare, religion, charity, or protection of the environment, they can be registered under this Act.
#
# Regarding the alteration of the memorandum and articles of association for companies with charitable objectives, the Act does not specifically mention any provisions. However, it can be inferred that such alterations can be made by following the general provisions of the Act, which require a special resolution passed by the company. The Registrar must then register the alteration within 30 days for it to have any effect.
#
# It is important to note that any alteration of the memorandum that purports to give any person a right to participate in the divisible profits of the company, other than as a member, shall be void for companies limited by guarantee and not having a share capital.
#
#    Iteration - 3  ▷▶
#
# ** Unanswered Questions **
# '4. What is the role of the Central Government in the registration process of companies under section 8 of the Companies Act?'
# '6. Are there any limitations or restrictions on the activities of companies registered under section 8 of the Companies Act?'
# '7. What are the specific requirements for a company to register under section 8 of the Companies Act?'
# '8. How does the liability of the members of a company registered under section 8 of the Companies Act differ from other companies?'
# '9. What steps should a company registered under section 8 of the Companies Act take to ensure the consent of secured creditors during the registration process?'
# '10. What documents need to be submitted by the members or partners of a company registered under section 8 of the Companies Act for the dissolution of the company as a partnership firm?'
# '11. How can a person or association of persons with charitable objectives be registered as a limited company under Section 8 of the Companies Act?'
# '12. What are the general provisions of the Companies Act that need to be followed for making alterations to the memorandum and articles of association for companies with charitable objectives?'
# '13. What is the timeframe within which the Registrar must register the alteration of the memorandum and articles of association for companies with charitable objectives under Section 8 of the Companies Act?'
# '14. What are the implications of making an alteration to the memorandum that gives a person a right to participate in the divisible profits of a company registered under Section 8 of the Companies Act?'
# ** 🤔 Next Questions I must ask: **
#  6 Are there any limitations or restrictions on the activities of companies registered under section 8 of the Companies Act?
# ** Answer **
#  Based on the information provided in the context, there are limitations and restrictions on the activities of companies registered under section 8 of the Companies Act. These limitations and restrictions include:
#
# 1. Companies registered under section 8 must have specific objects specified in clause (a) of sub-section (1) and must adhere to the restrictions and prohibitions mentioned in clauses (b) and (c) of that sub-section.
#
# 2. The Central Government has the authority to grant a license to such companies, subject to certain conditions deemed fit by the government. This may include changing the company's name by omitting the word "Limited" or "Private Limited".
#
# 3. The powers of an unlimited company, upon registration as a limited company, are restricted in terms of increasing the nominal amount of its share capital and providing that a portion of its share capital shall not be capable of being called-up except in the event of winding up.
#
# 4. The powers of a limited company to determine that a portion of its share capital shall not be capable of being called-up except in the event of winding up also apply.
#
# 5. The company cannot alter any provisions contained in any day-to-day operation on overdraft, cash credit, or other accounts by means of which the arrangement is actually availed of.
#
# 6. The company's Board of Directors can impose restrictions and conditions on the exercise of powers specified in this section, subject to the approval of the company in a general meeting.
#
# In summary, companies registered under section 8 of the Companies Act have limitations and restrictions on their activities, including specific objects, restrictions on share capital, and limitations on altering provisions related to day-to-day operations.
#
#    Iteration - 4  ▷▶
#
# ** Unanswered Questions **
# '4. What is the role of the Central Government in the registration process of companies under section 8 of the Companies Act?'
# '7. What are the specific requirements for a company to register under section 8 of the Companies Act?'
# '8. How does the liability of the members of a company registered under section 8 of the Companies Act differ from other companies?'
# '9. What steps should a company registered under section 8 of the Companies Act take to ensure the consent of secured creditors during the registration process?'
# '10. What documents need to be submitted by the members or partners of a company registered under section 8 of the Companies Act for the dissolution of the company as a partnership firm?'
# '11. How can a person or association of persons with charitable objectives be registered as a limited company under Section 8 of the Companies Act?'
# '12. What are the general provisions of the Companies Act that need to be followed for making alterations to the memorandum and articles of association for companies with charitable objectives?'
# '13. What is the timeframe within which the Registrar must register the alteration of the memorandum and articles of association for companies with charitable objectives under Section 8 of the Companies Act?'
# '14. What are the implications of making an alteration to the memorandum that gives a person a right to participate in the divisible profits of a company registered under Section 8 of the Companies Act?'
# '15. What are the specific conditions that the Central Government may impose when granting a license to companies registered under section 8 of the Companies Act?'
# '16. Can a company registered under section 8 of the Companies Act change its name by omitting the word "Limited" or "Private Limited" without obtaining a license from the Central Government?'
# '17. How does the restriction on increasing the nominal amount of share capital affect the powers of an unlimited company that registers under section 8 of the Companies Act?'
# '18. What are the potential consequences if a company registered under section 8 of the Companies Act alters provisions related to day-to-day operations on overdraft, cash credit, or other accounts without following the prescribed restrictions?'
# ** 🤔 Next Questions I must ask: **
#  11 How can a person or association of persons with charitable objectives be registered as a limited company under Section 8 of the Companies Act?
# ** Answer **
#  To register as a limited company under Section 8 of the Companies Act, a person or association of persons must meet certain criteria. Firstly, their objectives must be charitable, such as promoting welfare, religion, charity, or the protection of the environment. Secondly, they must intend to use any profits or income to promote these objectives. Lastly, they must prohibit the payment of dividends to their members.
#
# To register, the person or association must apply for a license from the Central Government, following the prescribed manner and conditions. The Registrar will then register them as a company under Section 8 without the addition of the word "Limited" or "Private Limited" to their name.
#
# Before granting the license, the company must be given a reasonable opportunity to be heard, and the Tribunal must consider the company's transactions and obligations.
#
# The registration process involves submitting an application in the prescribed form, stating the name of the company, its registered office, its objects, and the liability of its members. The application must also include the consent of the first directors and their interests in other firms or bodies corporate.
#
# Once all the required documents and information are submitted, the Registrar will register the company and issue a certificate of incorporation.
#
#     Max Iterations Reached. Compiling the results ...
#
# Section 8 of the Companies Act, 2013 deals with the formulation of companies with charitable objects. It allows for the registration of companies that have charitable or socially beneficial objectives.
#
# To register as a limited company under Section 8, a person or association of persons must meet certain criteria. Firstly, their objectives must be charitable, such as promoting commerce, art, science, sports, education, research, social welfare, religion, charity, protection of environment, or any other similar object. These objectives should be clearly stated in the company's objects clause when applying for registration. Secondly, they must intend to use any profits or income to promote these objectives. Lastly, they must prohibit the payment of dividends to their members.
#
# The registration process involves submitting an application in the prescribed form, stating the name of the company, its registered office, its objects, and the liability of its members. The application must also include the consent of the first directors and their interests in other firms or bodies corporate. The company should ensure that secured creditors have given their consent or no objection to the company's registration, publish advertisements seeking objections, and file an affidavit from all members or partners stating that necessary documents will be submitted for the dissolution of the company as a partnership firm.
#
# Once all the required documents and information are submitted, the Registrar will register the company and issue a certificate of incorporation. The Registrar must register any alteration of the memorandum and articles of association within 30 days for it to have any effect. However, any alteration of the memorandum that purports to give any person a right to participate in the divisible profits of the company, other than as a member, shall be void for companies limited by guarantee and not having a share capital.
#
# Companies registered under section 8 of the Companies Act have limitations and restrictions on their activities. These include specific objects specified in clause (a) of sub-section (1) and adherence to the restrictions and prohibitions mentioned in clauses (b) and (c) of that sub-section. The Central Government has the authority to grant a license to such companies, subject to certain conditions deemed fit by the government. This may include changing the company's name by omitting the word "Limited" or "Private Limited".
#
# The powers of an unlimited company, upon registration as a limited company, are restricted in terms of increasing the nominal amount of its share capital and providing that a portion of its share capital shall not be capable of being called-up except in the event of winding up. The powers of a limited company to determine that a portion of its share capital shall not be capable of being called-up except in the event of winding up also apply.
#
# The company cannot alter any provisions contained in any day-to-day operation on overdraft, cash credit, or other accounts by means of which the arrangement is actually availed of. The company's Board of Directors can impose restrictions and conditions on the exercise of powers specified in this section, subject to the approval of the company in a general meeting.
#
# In conclusion, Section 8 of the Companies Act explains the formation of companies with charitable objects or purposes. It provides guidelines and regulations for companies that are established for charitable or non-profit purposes. The section outlines the requirements and procedures for incorporating such companies and the effect of registration. It also covers the alteration of the memorandum and articles of association of these companies. Companies registered under section 8 have limitations and restrictions on their activities, including specific objects, restrictions on share capital, and limitations on altering provisions related to day-to-day operations.

# %%
print(
            chalk.bg_yellow_bright.black.bold(
                "\n ✔✔  Max Iterations Reached. Compiling the results ...    \n"
            )
        )
# Out:
#  ✔✔  Max Iterations Reached. Compiling the results ...
