# %% [markdown]
# # Create a Research Agent

# %% [markdown]
# This is a concept agent that is inspired by my process of researching on a subject. <br>
# I also took some inspiration from BabyAGI (without tools) implementation

# %%
from dotenv import load_dotenv

load_dotenv("./.env")
import uuid
import os
from langchain.chat_models import ChatOpenAI
from langchain.embeddings import OpenAIEmbeddings
from langchain.prompts import PromptTemplate
from yachalk import chalk

# %%
text_embedding_model = "text-embedding-ada-002"
embeddings = OpenAIEmbeddings(model=text_embedding_model)

# %% [markdown]
# ## Set up the vector store

# %%
use_localdb = False

SUPABASE_PASSWORD = os.environ["SUPABASE_PASSWORD"]
SUPABASE_DBUSER = os.environ["SUPABASE_DBUSER"]
SUPABASE_DATABASE = os.environ["SUPABASE_DATABASE"]
supabasedb_string = f"postgresql://{SUPABASE_DBUSER}:{SUPABASE_PASSWORD}@db.doxggeyqopdnxfhseufq.supabase.co:5432/{SUPABASE_DATABASE}"

PGVECTOR_USER = os.environ["PGVECTOR_USER"]
PGVECTOR_PASSWORD = os.environ["PGVECTOR_PASSWORD"]
PGVECTOR_DATABASE = os.environ["PGVECTOR_DATABASE"]
localdb_string = f"postgresql://{PGVECTOR_USER}:{PGVECTOR_PASSWORD}@localhost:5432/{PGVECTOR_DATABASE}"

connection_string = localdb_string if use_localdb else supabasedb_string

# %%
## Law store
from langchain.vectorstores import PGVector

law_compilation_store = PGVector(
    collection_name="law_compilation",
    connection_string=connection_string,
    embedding_function=embeddings,
)

## Mahabharata Store
mahabharata_store = PGVector(
    collection_name="mahabharat_combined_text",
    connection_string=connection_string,
    embedding_function=embeddings,
)

# %% [markdown]
# ### Supabase vector store for storing runs
#
# The supabase client here is not used as a vector store.
# I am only using it to save the runs data.
# You can remove it if you dont need it.

# %%
from supabase.client import Client, create_client
from langchain.vectorstores import SupabaseVectorStore

supabase_url = os.environ.get("SUPABASE_URL")
supabase_key = os.environ.get("SUPABASE_SERVICE_KEY")
supabase: Client = create_client(supabase_url, supabase_key)

runs_store = SupabaseVectorStore(
    embedding=embeddings, client=supabase, table_name="runs", query_name="match_runs"
)

# ## Testing store
# run_id = str(uuid.uuid4())
# runs_store.add_texts(texts=["testing the store"], metadatas=[{"key": "value"}], ids=[run_id])
# matched_docs = runs_store.similarity_search_with_relevance_scores("testing store", 1)
# matched_docs

# %% [markdown]
# ### Import Chains

# %% [markdown]
# #### Question creator
#
# Generate new questions based on
#
# -   `question` - Original question. This is important so that the pertinence to the original question is always maintained. Or else the context can diverge quickly into impertinent results.
# -   `unanswered_questions`: So that the new questions do not overlap with the old ones.
# -   `context`: The document found during the current run. So the questions are derived from the fresh information based on the current question being asked.
# -   `num_questions`: Configurable hyper parameter.
# -   `start_id`: This is passed so that the ids of the newly generated question do overlap with the current list.
#
# ---
#
# #### Most pertinent Question chain
#
# Pick the most pertinent question out of the given list of questions <br>
# I am not using any additional context other than the `original_question` for decising the pertinence.
#
# ---
#
# #### Retrieval QA
#
# This chain is used to answer the intermediate questions. The idea is to generate succinct answers which can be used as notes to finally answer the original question
#
# ---
#
# #### Result Analyser
#
# Not using this right now. I am not able to get this piece working well. So currently I will just run the agent for a fixed number of iterations and then compile the answer.

# %%
## Import all the chains.
from chains_v2.create_questions import QuestionCreationChain
from chains_v2.most_pertinent_question import MostPertinentQuestion
from chains_v2.retrieval_qa import retrieval_qa
from chains_v2.research_compiler import research_compiler
from chains_v2.question_atomizer import QuestionAtomizer

## Model with parameters
gpt3t = "gpt-3.5-turbo"


def language_model(
    model_name: str = gpt3t, temperature: float = 0, verbose: bool = False
):
    llm = ChatOpenAI(model_name=model_name, temperature=temperature, verbose=verbose)
    return llm

# %% [markdown]
# ### Importing Question helpers

# %%
from helpers.response_helpers import result2QuestionsList
from helpers.response_helpers import qStr2Dict
from helpers.questions_helper import getAnsweredQuestions
from helpers.questions_helper import getUnansweredQuestions
from helpers.questions_helper import getSubQuestions
from helpers.questions_helper import getHopQuestions
from helpers.questions_helper import getLastQuestionId
from helpers.questions_helper import markAnswered
from helpers.questions_helper import getQuestionById

# %% [markdown]
# # The Research Agent

# %% [markdown]
# Question Data Schema
#
# ```
#   Question: {
#     id: int,
#     question: string,
#     type: 'subquestion' | 'hops',
#     status: 'answered' | 'unanswered',
#     answer: string,
#     documents: []
#   }
# ```

# %%
run_id = str(uuid.uuid4())
scratchpad = {
    "original_question": "What is the procedure for winding down a private limited company?",
    "questions": [],  # list of type Question
}
verbose = False
max_iterations = 3
current_iteration = 0
num_atomistic_questions = 2
num_questions_per_iteration = 4
question_atomizer_temperature = 0
question_creation_temperature = 0.2
question_prioritisation_temperature = 0
qa_temperature = 0
analyser_temperature = 0
intermediate_answers_length = 200
answer_length = 500
store = law_compilation_store

## ---- The researcher ----- ##

## Step 0. Prepare the initial set of questions
question_atomizer = QuestionAtomizer.from_llm(
    llm=language_model(temperature=question_atomizer_temperature), verbose=verbose
)

atomized_questions_response = question_atomizer.run(
    question=scratchpad["original_question"],
    num_questions=num_atomistic_questions,
)

scratchpad["questions"] += result2QuestionsList(
    question_response=atomized_questions_response,
    type="subquestion",
    status="unanswered",
)

for q in scratchpad["questions"]:
    q["answer"], q["documents"] = retrieval_qa(
        llm=language_model(temperature=qa_temperature, verbose=verbose),
        retriever=store.as_retriever(
            search_type="mmr", search_kwargs={"k": 5, "fetch_k": 10}
        ),
        question=q["question"],
        answer_length=intermediate_answers_length,
        verbose=verbose,
    )
    q["status"] = "answered"

current_context = "".join(
    f"\n{q['id']}. {q['question']}\n{q['answer']}\n" for q in scratchpad["questions"]
)

print(
    chalk.blue_bright("** Atomistic Sub Questions **"),
    chalk.blue(current_context),
)

scratchpad_temp = scratchpad.copy()
verbose = False
while True:
    current_iteration += 1
    print(chalk.bg_red_bright.black.bold(f"\n   Iteration - {current_iteration}   \n"))

    # STEP 1: create questions
    start_id = getLastQuestionId(scratchpad_temp["questions"]) + 1
    question_creation_chain = QuestionCreationChain.from_llm(
        language_model(temperature=question_creation_temperature), verbose=verbose
    )
    questions_response = question_creation_chain.run(
        question=scratchpad_temp["original_question"],
        context=current_context,
        previous_questions=[
            "".join(f"\n{q['question']}") for q in scratchpad_temp["questions"]
        ],
        num_questions=num_questions_per_iteration,
        start_id=start_id,
    )
    scratchpad_temp["questions"] += result2QuestionsList(
        question_response=questions_response,
        type="hop",
        status="unanswered",
    )

    # STEP 2: Choose question for current iteration
    unanswered = getUnansweredQuestions(scratchpad_temp["questions"])
    unanswered_questions_prompt = (
        "[" + "".join([f"\n{q['id']}. {q['question']}" for q in unanswered]) + "]"
    )
    print(
        chalk.cyan_bright("** Unanswered Questions **"),
        chalk.cyan("".join([f"\n'{q['id']}. {q['question']}'" for q in unanswered])),
    )
    most_pertinent_question = MostPertinentQuestion.from_llm(
        language_model(temperature=question_creation_temperature), verbose=verbose
    )
    response = most_pertinent_question.run(
        original_question=scratchpad_temp["original_question"],
        unanswered_questions=unanswered_questions_prompt,
    )

    current_question_dict = qStr2Dict(question=response)
    current_question_id = current_question_dict["id"]
    
    current_question = getQuestionById(scratchpad['questions'], current_question_id)

    print(
        chalk.magenta.bold("** Next Questions **\n"),
        chalk.magenta(current_question_id),
        chalk.magenta(current_question['question']),
    )

    # STEP 3: Answer the question
    current_question["answer"], current_question["documents"] = retrieval_qa(
        llm=language_model(temperature=qa_temperature, verbose=verbose),
        retriever=store.as_retriever(
            search_type="mmr", search_kwargs={"k": 5, "fetch_k": 10}
        ),
        question=current_question["question"],
        answer_length=intermediate_answers_length,
        verbose=verbose,
    )
    markAnswered(scratchpad_temp["questions"], current_question_id)

    print(
        chalk.yellow_bright.bold("** Answer **\n"),
        chalk.yellow_bright(current_question["answer"]))

    current_context = current_question["answer"]
    
    if current_iteration > max_iterations:
        print(chalk.bg_red_bright.black.bold("\n    Max Iterations Reached. Compiling the results ...    \n"))
        break



## STEP 4: Compile the research
answered_questions = getAnsweredQuestions(scratchpad['questions'])
answered_questions_prompt = "[" + "".join([ f"{{ Question: {q['question']}, Answer: {q['answer']} }}" for q in answered_questions ]) + "]"
result = research_compiler(
    llm = language_model(temperature=qa_temperature, verbose=verbose),
    question = scratchpad['original_question'], 
    notes = answered_questions_prompt, 
    answer_length=answer_length,
    verbose = verbose)

print(chalk.italic.white_bright((result['text'])))

# current_question = response
## Collect initial document with semantic search.
# Out:
# ** Atomistic Sub Questions **
# 1. What is the procedure for winding down a private limited company?
# The procedure for winding down a private limited company depends on the circumstances. If the company is dissolved, ceases to carry on business, or is only carrying on business for the purpose of winding up its affairs, it may be wound up. If the company is unable to pay its debts or if the Tribunal deems it just and equitable, the company may also be wound up. The mode of proceedings for winding up by the Tribunal, as well as for voluntary winding up by members or creditors, is specified. Meetings of creditors and members may be held in connection with the winding up process. Costs, charges, and expenses incurred in the winding up, including the fee of the Company Liquidator, are payable out of the company's assets in priority to other claims. The manner of disposing of the liquidator may be directed by the Tribunal or by special resolution with the approval of creditors. After five years from the dissolution of the company, no responsibility shall devolve.
#
# 2. Is there a specific process to follow when winding down a private limited company?
# Yes, there is a specific process to follow when winding down a private limited company. The company must cease to carry on its business, except for activities necessary for the beneficial winding up of its affairs. The corporate state and powers of the company will continue until it is dissolved. An unregistered company can be wound up if it is dissolved, has ceased to carry on business, is only carrying on business for the purpose of winding up its affairs, is unable to pay its debts, or if the Tribunal deems it just and equitable. The process for winding up a company can be determined by the Tribunal, and there are specific provisions for voluntary winding up by members or creditors, as well as for meetings of creditors and members. The company liquidator, appointed by the Tribunal, is responsible for disposing of the company's assets, discharging its debts, and calling a general meeting to present the final winding up accounts.
#
#
#    Iteration - 1
#
# ** Unanswered Questions **
# '3. What are the circumstances under which a private limited company may be wound up?'
# '4. What are the specific provisions for voluntary winding up by members or creditors?'
# '5. Who is responsible for disposing of the company's assets and discharging its debts during the winding up process?'
# '6. What is the timeline for the final winding up of a private limited company after it is dissolved?'
# ** Next Questions **
#  3 What are the circumstances under which a private limited company may be wound up?
# ** Answer **
#  A private limited company may be wound up under the following circumstances:
# 1. If the company is dissolved, ceases to carry on business, or is carrying on business only for the purpose of winding up its affairs.
# 2. If the company is unable to pay its debts.
# 3. If the Tribunal determines that it is just and equitable for the company to be wound up.
# Additionally, an unregistered company may be wound up if it does anything or suffers anything done that puts a person in a better position in the event of the company going into liquidation, within six months of making the winding up of the company. If the company is wound up voluntarily, it can be done through a resolution passed in a general meeting. If the Central Government deems it necessary, it can present a petition for the winding up of the company on the grounds of it being just.
#
#    Iteration - 2
#
# ** Unanswered Questions **
# '4. What are the specific provisions for voluntary winding up by members or creditors?'
# '5. Who is responsible for disposing of the company's assets and discharging its debts during the winding up process?'
# '6. What is the timeline for the final winding up of a private limited company after it is dissolved?'
# '7. What are the consequences for a private limited company if it continues to carry on business solely for the purpose of winding up its affairs?'
# '8. How does the Tribunal determine if it is just and equitable for a private limited company to be wound up?'
# '9. What actions or circumstances would put a person in a better position in the event of a private limited company going into liquidation?'
# '10. Under what circumstances would the Central Government present a petition for the winding up of a private limited company?'
# ** Next Questions **
#  4 What are the specific provisions for voluntary winding up by members or creditors?
# ** Answer **
#  The specific provisions for voluntary winding up by members or creditors include the following:
# - The company must cease to carry on its business, except as necessary for the beneficial winding up of its affairs.
# - The corporate state and powers of the company will continue until it is dissolved.
# - The company must hold a meeting of its creditors, along with the meeting of its members where the resolution for voluntary winding up is proposed.
# - The company must send a notice of the creditors' meeting.
# - The members of the company will be liable to contribute to the assets of the company to pay off its debts, liabilities, and winding up expenses.
# - The rights of the contributories (members who are liable to contribute) will be adjusted among themselves.
# - The provisions of the Act regarding reduction of capital will be given effect.
#
#    Iteration - 3
#
# ** Unanswered Questions **
# '5. Who is responsible for disposing of the company's assets and discharging its debts during the winding up process?'
# '6. What is the timeline for the final winding up of a private limited company after it is dissolved?'
# '7. What are the consequences for a private limited company if it continues to carry on business solely for the purpose of winding up its affairs?'
# '8. How does the Tribunal determine if it is just and equitable for a private limited company to be wound up?'
# '9. What actions or circumstances would put a person in a better position in the event of a private limited company going into liquidation?'
# '10. Under what circumstances would the Central Government present a petition for the winding up of a private limited company?'
# '11. What is the purpose of holding a meeting of creditors and members when proposing a resolution for voluntary winding up?'
# '12. How are the rights of the contributories adjusted among themselves during the winding up process?'
# '13. What are the specific provisions of the Act regarding the reduction of capital that will be given effect during the winding up of a private limited company?'
# '14. How are the assets of the company used to pay off its debts, liabilities, and winding up expenses during the voluntary winding up process?'
# ** Next Questions **
#  5 Who is responsible for disposing of the company's assets and discharging its debts during the winding up process?
# ** Answer **
#  The responsibility for disposing of the company's assets and discharging its debts during the winding up process depends on the type of winding up. In the case of winding up by the Tribunal, the liquidator is responsible for disposing of the assets and discharging the debts as directed by the Tribunal. In the case of voluntary winding up, the company, with the prior approval of the creditors, directs the manner in which the liquidator disposes of the assets and discharges the debts. After the dissolution of the company, the liquidator must ensure that the assets have been disposed of and the debts fully discharged or satisfied to the creditors' satisfaction. The liquidator then calls a general meeting of the company to lay the final winding up accounts before it. If the company has any outstanding debts or liabilities, the members may be liable to contribute to the assets of the company to cover these obligations.
#
#    Iteration - 4
#
# ** Unanswered Questions **
# '6. What is the timeline for the final winding up of a private limited company after it is dissolved?'
# '7. What are the consequences for a private limited company if it continues to carry on business solely for the purpose of winding up its affairs?'
# '8. How does the Tribunal determine if it is just and equitable for a private limited company to be wound up?'
# '9. What actions or circumstances would put a person in a better position in the event of a private limited company going into liquidation?'
# '10. Under what circumstances would the Central Government present a petition for the winding up of a private limited company?'
# '11. What is the purpose of holding a meeting of creditors and members when proposing a resolution for voluntary winding up?'
# '12. How are the rights of the contributories adjusted among themselves during the winding up process?'
# '13. What are the specific provisions of the Act regarding the reduction of capital that will be given effect during the winding up of a private limited company?'
# '14. How are the assets of the company used to pay off its debts, liabilities, and winding up expenses during the voluntary winding up process?'
# '15. What is the role of the liquidator in the winding up process of a private limited company?'
# '16. How does the company obtain prior approval from the creditors for the disposal of assets and discharge of debts in voluntary winding up?'
# '17. What are the potential liabilities of the members if the company has outstanding debts or liabilities during the winding up process?'
# '18. What is the purpose of calling a general meeting of the company after the dissolution for laying the final winding up accounts?'
# ** Next Questions **
#  6 What is the timeline for the final winding up of a private limited company after it is dissolved?
# ** Answer **
#  The timeline for the final winding up of a private limited company after it is dissolved is not provided in the given context.
#
#     Max Iterations Reached. Compiling the results ...
#
# The procedure for winding down a private limited company depends on the circumstances. If the company is dissolved, ceases to carry on business, or is only carrying on business for the purpose of winding up its affairs, it may be wound up. If the company is unable to pay its debts or if the Tribunal deems it just and equitable, the company may also be wound up.
#
# The mode of proceedings for winding up by the Tribunal, as well as for voluntary winding up by members or creditors, is specified. Meetings of creditors and members may be held in connection with the winding up process. Costs, charges, and expenses incurred in the winding up, including the fee of the Company Liquidator, are payable out of the company's assets in priority to other claims. The manner of disposing of the liquidator may be directed by the Tribunal or by special resolution with the approval of creditors. After five years from the dissolution of the company, no responsibility shall devolve.
#
# The specific process to follow when winding down a private limited company involves several steps. First, the company must cease to carry on its business, except for activities necessary for the beneficial winding up of its affairs. The corporate state and powers of the company will continue until it is dissolved. An unregistered company can be wound up if it is dissolved, has ceased to carry on business, is only carrying on business for the purpose of winding up its affairs, is unable to pay its debts, or if the Tribunal deems it just and equitable.
#
# The process for winding up a company can be determined by the Tribunal, and there are specific provisions for voluntary winding up by members or creditors, as well as for meetings of creditors and members. The company liquidator, appointed by the Tribunal, is responsible for disposing of the company's assets, discharging its debts, and calling a general meeting to present the final winding up accounts.
#
# A private limited company may be wound up under the following circumstances:
# 1. If the company is dissolved, ceases to carry on business, or is carrying on business only for the purpose of winding up its affairs.
# 2. If the company is unable to pay its debts.
# 3. If the Tribunal determines that it is just and equitable for the company to be wound up.
#
# Additionally, an unregistered company may be wound up if it does anything or suffers anything done that puts a person in a better position in the event of the company going into liquidation, within six months of making the winding up of the company. If the company is wound up voluntarily, it can be done through a resolution passed in a general meeting. If the Central Government deems it necessary, it can present a petition for the winding up of the company on the grounds of it being just.
#
# The specific provisions for voluntary winding up by members or creditors include the following:
# - The company must cease to carry on its business, except as necessary for the beneficial winding up of its affairs.
# - The corporate state and powers of the company will continue until it is dissolved.
# - The company must hold a meeting of its creditors, along with the meeting of its members where the resolution for voluntary winding up is proposed.
# - The company must send a notice of the creditors' meeting.
# - The members of the company will be liable to contribute to the assets of the company to pay off its debts, liabilities, and winding up expenses.
# - The rights of the contributories (members who are liable to contribute) will be adjusted among themselves.
# - The provisions of the Act regarding reduction of capital will be given effect.
#
# The responsibility for disposing of the company's assets and discharging its debts during the winding up process depends on the type of winding up. In the case of winding up by the Tribunal, the liquidator is responsible for disposing of the assets and discharging the debts as directed by the Tribunal. In the case of voluntary winding up, the company, with the prior approval of the creditors, directs the manner in which the liquidator disposes of the assets and discharges the debts. After the dissolution of the company, the liquidator must ensure that the assets have been disposed of and the debts fully discharged or satisfied to the creditors' satisfaction. The liquidator then calls a general meeting of the company to lay the final winding up accounts before it. If the company has any outstanding debts or liabilities, the members may be liable to contribute to the assets of the company to cover these obligations.
#
# The timeline for the final winding up of a private limited company after it is dissolved is not provided in the given context. Therefore, the specific timeline for the final winding up process remains unclear.
