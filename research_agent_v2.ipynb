# %% [markdown]
# # Create a Research Agent

# %% [markdown]
# This is a concept agent that is inspired by my process of researching on a subject. <br>
# I also took some inspiration from BabyAGI (without tools) implementation

# %%
from dotenv import load_dotenv

load_dotenv("./.env")
import uuid
import os
from langchain.chat_models import ChatOpenAI
from langchain.embeddings import OpenAIEmbeddings
from langchain.prompts import PromptTemplate
from yachalk import chalk

# %%
text_embedding_model = "text-embedding-ada-002"
embeddings = OpenAIEmbeddings(model=text_embedding_model)

# %% [markdown]
# ## Set up the vector store

# %%
use_localdb = False

SUPABASE_PASSWORD = os.environ["SUPABASE_PASSWORD"]
SUPABASE_DBUSER = os.environ["SUPABASE_DBUSER"]
SUPABASE_DATABASE = os.environ["SUPABASE_DATABASE"]
supabasedb_string = f"postgresql://{SUPABASE_DBUSER}:{SUPABASE_PASSWORD}@db.doxggeyqopdnxfhseufq.supabase.co:5432/{SUPABASE_DATABASE}"

PGVECTOR_USER = os.environ["PGVECTOR_USER"]
PGVECTOR_PASSWORD = os.environ["PGVECTOR_PASSWORD"]
PGVECTOR_DATABASE = os.environ["PGVECTOR_DATABASE"]
localdb_string = f"postgresql://{PGVECTOR_USER}:{PGVECTOR_PASSWORD}@localhost:5432/{PGVECTOR_DATABASE}"

connection_string = localdb_string if use_localdb else supabasedb_string

# %%
## Law store
from langchain.vectorstores import PGVector

law_compilation_store = PGVector(
    collection_name="law_compilation",
    connection_string=connection_string,
    embedding_function=embeddings,
)

## Mahabharata Store
mahabharata_store = PGVector(
    collection_name="mahabharat_combined_text",
    connection_string=connection_string,
    embedding_function=embeddings,
)

# %% [markdown]
# ### Supabase vector store for storing runs
#
# The supabase client here is not used as a vector store.
# I am only using it to save the runs data.
# You can remove it if you dont need it.

# %%
from supabase.client import Client, create_client
from langchain.vectorstores import SupabaseVectorStore

supabase_url = os.environ.get("SUPABASE_URL")
supabase_key = os.environ.get("SUPABASE_SERVICE_KEY")
supabase: Client = create_client(supabase_url, supabase_key)

runs_store = SupabaseVectorStore(
    embedding=embeddings, client=supabase, table_name="runs", query_name="match_runs"
)

# ## Testing store
# run_id = str(uuid.uuid4())
# runs_store.add_texts(texts=["testing the store"], metadatas=[{"key": "value"}], ids=[run_id])
# matched_docs = runs_store.similarity_search_with_relevance_scores("testing store", 1)
# matched_docs

# %% [markdown]
# ### Import Chains

# %% [markdown]
# #### Question creator
#
# Generate new questions based on
#
# -   `question` - Original question. This is important so that the pertinence to the original question is always maintained. Or else the context can diverge quickly into impertinent results.
# -   `unanswered_questions`: So that the new questions do not overlap with the old ones.
# -   `context`: The answer to the last question.
# -   `num_questions`: Configurable hyper parameter.
# -   `start_id`: This is passed so that the ids of the newly generated question do overlap with the current list.
#
# ---
#
# #### Most pertinent Question chain
#
# Pick the most pertinent question out of the given list of questions <br>
# I am not using any additional context other than the `original_question` for decising the pertinence.
#
# ---
#
# #### Retrieval QA
#
# This chain is used to answer the intermediate questions. The idea is to generate succinct answers which can be used as notes to finally answer the original question
#
# ---
#
# #### Result Analyser
#
# Not using this right now. I am not able to get this piece working well. So currently I will just run the agent for a fixed number of iterations and then compile the answer.

# %%
## Import all the chains.
from chains_v2.create_questions import QuestionCreationChain
from chains_v2.most_pertinent_question import MostPertinentQuestion
from chains_v2.retrieval_qa import retrieval_qa
from chains_v2.research_compiler import research_compiler
from chains_v2.question_atomizer import QuestionAtomizer

## Model with parameters
gpt3t = "gpt-3.5-turbo"


def language_model(
    model_name: str = gpt3t, temperature: float = 0, verbose: bool = False
):
    llm = ChatOpenAI(model_name=model_name, temperature=temperature, verbose=verbose)
    return llm

# %% [markdown]
# ### Importing Question helpers

# %%
from helpers.response_helpers import result2QuestionsList
from helpers.response_helpers import qStr2Dict
from helpers.questions_helper import getAnsweredQuestions
from helpers.questions_helper import getUnansweredQuestions
from helpers.questions_helper import getSubQuestions
from helpers.questions_helper import getHopQuestions
from helpers.questions_helper import getLastQuestionId
from helpers.questions_helper import markAnswered
from helpers.questions_helper import getQuestionById

# %% [markdown]
# # The Research Agent

# %% [markdown]
# Question Data Schema
#
# ```
#   Question: {
#     id: int,
#     question: string,
#     type: 'subquestion' | 'hops',
#     status: 'answered' | 'unanswered',
#     answer: string,
#     documents: []
#   }
# ```

# %%
run_id = str(uuid.uuid4())
scratchpad = {
    "original_question": "Exploain section 8 of the companies act?",
    "questions": [],  # list of type Question
}
verbose = False
max_iterations = 5
current_iteration = 0
num_atomistic_questions = 2
num_questions_per_iteration = 4
question_atomizer_temperature = 0
question_creation_temperature = 0.4
question_prioritisation_temperature = 0
qa_temperature = 0
analyser_temperature = 0
intermediate_answers_length = 200
answer_length = 500
store = law_compilation_store

## ---- The researcher ----- ##

## Step 0. Prepare the initial set of questions
question_atomizer = QuestionAtomizer.from_llm(
    llm=language_model(temperature=question_atomizer_temperature), verbose=verbose
)

atomized_questions_response = question_atomizer.run(
    question=scratchpad["original_question"],
    num_questions=num_atomistic_questions,
)

scratchpad["questions"] += result2QuestionsList(
    question_response=atomized_questions_response,
    type="subquestion",
    status="unanswered",
)

for q in scratchpad["questions"]:
    q["answer"], q["documents"] = retrieval_qa(
        llm=language_model(temperature=qa_temperature, verbose=verbose),
        retriever=store.as_retriever(
            search_type="mmr", search_kwargs={"k": 5, "fetch_k": 10}
        ),
        question=q["question"],
        answer_length=intermediate_answers_length,
        verbose=verbose,
    )
    q["status"] = "answered"
    print(chalk.magenta.bold(f"** Sub Question **\n{q['question']}\n{q['answer']}\n"))

current_context = "".join(
    f"\n{q['id']}. {q['question']}\n{q['answer']}\n" for q in scratchpad["questions"]
)


verbose = False
while True:
    current_iteration += 1
    print(
        chalk.bg_yellow_bright.black.bold(f"\n   Iteration - {current_iteration}  ▷▶  \n")
    )

    # STEP 1: create questions
    start_id = getLastQuestionId(scratchpad["questions"]) + 1
    question_creation_chain = QuestionCreationChain.from_llm(
        language_model(temperature=question_creation_temperature), verbose=verbose
    )
    questions_response = question_creation_chain.run(
        question=scratchpad["original_question"],
        context=current_context,
        previous_questions=[
            "".join(f"\n{q['question']}") for q in scratchpad["questions"]
        ],
        num_questions=num_questions_per_iteration,
        start_id=start_id,
    )
    scratchpad["questions"] += result2QuestionsList(
        question_response=questions_response,
        type="hop",
        status="unanswered",
    )

    # STEP 2: Choose question for current iteration
    unanswered = getUnansweredQuestions(scratchpad["questions"])
    unanswered_questions_prompt = (
        "[" + "".join([f"\n{q['id']}. {q['question']}" for q in unanswered]) + "]"
    )
    print(
        chalk.cyan_bright("** Unanswered Questions **"),
        chalk.cyan("".join([f"\n'{q['id']}. {q['question']}'" for q in unanswered])),
    )
    most_pertinent_question = MostPertinentQuestion.from_llm(
        language_model(temperature=question_creation_temperature), verbose=verbose
    )
    response = most_pertinent_question.run(
        original_question=scratchpad["original_question"],
        unanswered_questions=unanswered_questions_prompt,
    )

    current_question_dict = qStr2Dict(question=response)
    current_question_id = current_question_dict["id"]

    current_question = getQuestionById(scratchpad["questions"], current_question_id)

    print(
        chalk.magenta.bold("** 🤔 Next Questions I must ask: **\n"),
        chalk.magenta(current_question_id),
        chalk.magenta(current_question["question"]),
    )

    # STEP 3: Answer the question
    current_question["answer"], current_question["documents"] = retrieval_qa(
        llm=language_model(temperature=qa_temperature, verbose=verbose),
        retriever=store.as_retriever(
            search_type="mmr", search_kwargs={"k": 5, "fetch_k": 10}
        ),
        question=current_question["question"],
        answer_length=intermediate_answers_length,
        verbose=verbose,
    )
    markAnswered(scratchpad["questions"], current_question_id)

    print(
        chalk.yellow_bright.bold("** Answer **\n"),
        chalk.yellow_bright(current_question["answer"]),
    )

    current_context = current_question["answer"]

    if current_iteration > max_iterations:
        print(
            chalk.bg_yellow_bright.black.bold(
                "\n ✔✔  Max Iterations Reached. Compiling the results ...    \n"
            )
        )
        break


## STEP 4: Compile the research
answered_questions = getAnsweredQuestions(scratchpad["questions"])
answered_questions_prompt = (
    "["
    + "".join(
        [
            f"{{ Question: {q['question']}, Answer: {q['answer']} }}"
            for q in answered_questions
        ]
    )
    + "]"
)
result = research_compiler(
    llm=language_model(temperature=qa_temperature, verbose=verbose),
    question=scratchpad["original_question"],
    notes=answered_questions_prompt,
    answer_length=answer_length,
    verbose=verbose,
)

print(chalk.italic.white_bright((result["text"])))

# current_question = response
## Collect initial document with semantic search.
# Out:
# ** Sub Question **
# What is section 8 of the Companies Act?
# Section 8 of the Companies Act, 2013 deals with the formulation of companies with charitable objects. It states that if a person or an association of persons intends to register as a limited company under this Act and has the objective of promoting commerce, art, science, sports, education, research, social welfare, religion, charity, protection of environment, or any other similar object, they can do so with the satisfaction of the Central Government. This section allows for the registration of companies that have charitable or socially beneficial objectives.
#
# ** Sub Question **
# What does section 8 of the Companies Act explain?
# Section 8 of the Companies Act explains the formation of companies with charitable objects or purposes. This section provides guidelines and regulations for companies that are established for charitable or philanthropic purposes. It outlines the requirements and procedures for incorporating such companies and the effect of registration. Section 8 also covers the alteration of memorandum and articles for these companies. It is important to note that this information is based solely on the context provided and may not encompass all the details and provisions of Section 8.
#
#
#    Iteration - 1  ▷▶
#
# ** Unanswered Questions **
# '3. What are some examples of charitable objects or purposes that can be registered under Section 8 of the Companies Act?'
# '4. What is the role of the Central Government in the registration process of companies with charitable objects under Section 8 of the Companies Act?'
# '5. How does Section 8 of the Companies Act address the alteration of memorandum and articles for companies with charitable objectives?'
# '6. Are there any specific requirements or qualifications that a person or association of persons must meet in order to register a company under Section 8 of the Companies Act?'
# ** 🤔 Next Questions I must ask: **
#  3 What are some examples of charitable objects or purposes that can be registered under Section 8 of the Companies Act?
# ** Answer **
#  Some examples of charitable objects or purposes that can be registered under Section 8 of the Companies Act include the promotion of commerce, art, science, sports, education, research, social welfare, religion, charity, protection of the environment, and any other similar object. Additionally, activities such as eradicating extreme hunger and poverty, promoting education, gender equality, and women empowerment, reducing child mortality and improving maternal health, combating diseases like HIV/AIDS and malaria, ensuring environmental sustainability, enhancing vocational skills, and contributing to the Prime Minister's National Relief Fund or any other fund set up by the Central Government can be included in a company's Corporate Social Responsibility Policies.
#
#    Iteration - 2  ▷▶
#
# ** Unanswered Questions **
# '4. What is the role of the Central Government in the registration process of companies with charitable objects under Section 8 of the Companies Act?'
# '5. How does Section 8 of the Companies Act address the alteration of memorandum and articles for companies with charitable objectives?'
# '6. Are there any specific requirements or qualifications that a person or association of persons must meet in order to register a company under Section 8 of the Companies Act?'
# '7. What are some examples of activities that can be included in a company's Corporate Social Responsibility Policies under Section 8 of the Companies Act?'
# '8. Can a company registered under Section 8 of the Companies Act contribute to funds set up by the Central Government other than the Prime Minister's National Relief Fund?'
# '9. Is there a specific list of objects or purposes that can be included under Section 8 of the Companies Act, or can any similar object be registered?'
# '10. Are there any limitations or restrictions on the types of activities that can be registered under Section 8 of the Companies Act?'
# ** 🤔 Next Questions I must ask: **
#  6 Are there any specific requirements or qualifications that a person or association of persons must meet in order to register a company under Section 8 of the Companies Act?
# ** Answer **
#  Based on the information provided in the context, there are specific requirements and qualifications that a person or association of persons must meet in order to register a company under Section 8 of the Companies Act. These requirements include filing the memorandum and articles of the company, signed by all the subscribers to the memorandum, with the Registrar. Additionally, a declaration must be made by an advocate, chartered accountant, cost accountant, or company secretary in practice, who is engaged in the formation of the company, along with a person named in the articles as a director, manager, or secretary of the company, stating that all the requirements of the Companies Act and the rules made thereunder have been complied with. The company must also pay the necessary fees for registration. However, the specific qualifications or criteria for registering a company under Section 8 are not mentioned in the provided context.
#
#    Iteration - 3  ▷▶
#
# ** Unanswered Questions **
# '4. What is the role of the Central Government in the registration process of companies with charitable objects under Section 8 of the Companies Act?'
# '5. How does Section 8 of the Companies Act address the alteration of memorandum and articles for companies with charitable objectives?'
# '7. What are some examples of activities that can be included in a company's Corporate Social Responsibility Policies under Section 8 of the Companies Act?'
# '8. Can a company registered under Section 8 of the Companies Act contribute to funds set up by the Central Government other than the Prime Minister's National Relief Fund?'
# '9. Is there a specific list of objects or purposes that can be included under Section 8 of the Companies Act, or can any similar object be registered?'
# '10. Are there any limitations or restrictions on the types of activities that can be registered under Section 8 of the Companies Act?'
# '11. What are the specific requirements for filing the memorandum and articles of a company under Section 8 of the Companies Act?'
# '12. Who can make the declaration stating that all the requirements of the Companies Act and the rules made thereunder have been complied with for the registration of a company under Section 8?'
# '13. What is the process for paying the necessary fees for the registration of a company under Section 8 of the Companies Act?'
# '14. Are there any additional qualifications or criteria that need to be met in order to register a company under Section 8, which are not mentioned in the provided context?'
# ** 🤔 Next Questions I must ask: **
#  4 What is the role of the Central Government in the registration process of companies with charitable objects under Section 8 of the Companies Act?
# ** Answer **
#  The role of the Central Government in the registration process of companies with charitable objects under Section 8 of the Companies Act is to determine whether a person or association of persons seeking registration as a limited company meets the criteria for promoting commerce, art, science, sports, education, research, social welfare, religion, charity, protection of environment, or any other similar object. If it is proved to the satisfaction of the Central Government that the person or association of persons meets these criteria, the Central Government will register them as a company under Section 8. The company registered under this section will enjoy all the privileges and be subject to all the obligations of limited companies. The Central Government also has the authority to approve any alterations to the company's memorandum or articles and to direct the preparation of seals for the authentication of registration-related documents. The Central Government may appoint Registrars and other officers for the registration of companies and may provide resources for the administration of the registration process.
#
#    Iteration - 4  ▷▶
#
# ** Unanswered Questions **
# '5. How does Section 8 of the Companies Act address the alteration of memorandum and articles for companies with charitable objectives?'
# '7. What are some examples of activities that can be included in a company's Corporate Social Responsibility Policies under Section 8 of the Companies Act?'
# '8. Can a company registered under Section 8 of the Companies Act contribute to funds set up by the Central Government other than the Prime Minister's National Relief Fund?'
# '9. Is there a specific list of objects or purposes that can be included under Section 8 of the Companies Act, or can any similar object be registered?'
# '10. Are there any limitations or restrictions on the types of activities that can be registered under Section 8 of the Companies Act?'
# '11. What are the specific requirements for filing the memorandum and articles of a company under Section 8 of the Companies Act?'
# '12. Who can make the declaration stating that all the requirements of the Companies Act and the rules made thereunder have been complied with for the registration of a company under Section 8?'
# '13. What is the process for paying the necessary fees for the registration of a company under Section 8 of the Companies Act?'
# '14. Are there any additional qualifications or criteria that need to be met in order to register a company under Section 8, which are not mentioned in the provided context?'
# '15. What privileges and obligations do limited companies registered under Section 8 of the Companies Act enjoy and are subject to?'
# '16. Can the Central Government approve alterations to the memorandum or articles of a company registered under Section 8 of the Companies Act? If so, what is the process for obtaining this approval?'
# '17. What authority does the Central Government have in terms of directing the preparation of seals for the authentication of registration-related documents for companies registered under Section 8 of the Companies Act?'
# '18. How does the Central Government appoint Registrars and other officers for the registration of companies under Section 8 of the Companies Act? Are there any specific qualifications or criteria for these appointments?'
# ** 🤔 Next Questions I must ask: **
#  5 How does Section 8 of the Companies Act address the alteration of memorandum and articles for companies with charitable objectives?
# ** Answer **
#  Section 8 of the Companies Act addresses the formation of companies with charitable objectives. It states that if a person or association of persons proposed to be registered as a limited company has charitable objectives, such as the promotion of commerce, art, science, sports, education, research, social welfare, religion, charity, or protection of the environment, they can be registered under this Act.
#
# Regarding the alteration of memorandum and articles for companies with charitable objectives, the Act does not specifically mention this. However, Section 14 of the Act allows a company, by a special resolution, to alter its articles, including converting from a private company to a public company or vice versa. This suggests that companies with charitable objectives can also alter their articles through a special resolution.
#
# It is important to note that any alteration made under this section must be registered with the Registrar within 30 days to have legal effect.
#
#    Iteration - 5  ▷▶
#
# ** Unanswered Questions **
# '7. What are some examples of activities that can be included in a company's Corporate Social Responsibility Policies under Section 8 of the Companies Act?'
# '8. Can a company registered under Section 8 of the Companies Act contribute to funds set up by the Central Government other than the Prime Minister's National Relief Fund?'
# '9. Is there a specific list of objects or purposes that can be included under Section 8 of the Companies Act, or can any similar object be registered?'
# '10. Are there any limitations or restrictions on the types of activities that can be registered under Section 8 of the Companies Act?'
# '11. What are the specific requirements for filing the memorandum and articles of a company under Section 8 of the Companies Act?'
# '12. Who can make the declaration stating that all the requirements of the Companies Act and the rules made thereunder have been complied with for the registration of a company under Section 8?'
# '13. What is the process for paying the necessary fees for the registration of a company under Section 8 of the Companies Act?'
# '14. Are there any additional qualifications or criteria that need to be met in order to register a company under Section 8, which are not mentioned in the provided context?'
# '15. What privileges and obligations do limited companies registered under Section 8 of the Companies Act enjoy and are subject to?'
# '16. Can the Central Government approve alterations to the memorandum or articles of a company registered under Section 8 of the Companies Act? If so, what is the process for obtaining this approval?'
# '17. What authority does the Central Government have in terms of directing the preparation of seals for the authentication of registration-related documents for companies registered under Section 8 of the Companies Act?'
# '18. How does the Central Government appoint Registrars and other officers for the registration of companies under Section 8 of the Companies Act? Are there any specific qualifications or criteria for these appointments?'
# '19. Can companies with charitable objectives alter their articles through a special resolution under Section 14 of the Companies Act?'
# '20. What is the timeframe within which any alteration made under Section 8 must be registered with the Registrar to have legal effect?'
# '21. Are there any specific requirements or qualifications for companies with charitable objectives to convert from a private company to a public company or vice versa under Section 14 of the Companies Act?'
# '22. How does the alteration process for companies with charitable objectives differ from other companies under Section 14 of the Companies Act?'
# ** 🤔 Next Questions I must ask: **
#  8 Can a company registered under Section 8 of the Companies Act contribute to funds set up by the Central Government other than the Prime Minister's National Relief Fund?
# ** Answer **
#  Yes, a company registered under Section 8 of the Companies Act can contribute to funds set up by the Central Government other than the Prime Minister's National Relief Fund. Section 183 of the Companies Act allows the Board of Directors or any person or authority exercising the powers of the Board of Directors to contribute to the National Defence Fund or any other Fund approved by the Central Government for the purpose of national defence. This provision overrides any other provision in the Act or in the company's memorandum, articles, or any other instrument relating to the company. Therefore, a Section 8 company can make contributions to funds approved by the Central Government for purposes other than national defence, such as welfare, religion, charity, or protection of the environment.
#
#    Iteration - 6  ▷▶
#
# ** Unanswered Questions **
# '7. What are some examples of activities that can be included in a company's Corporate Social Responsibility Policies under Section 8 of the Companies Act?'
# '9. Is there a specific list of objects or purposes that can be included under Section 8 of the Companies Act, or can any similar object be registered?'
# '10. Are there any limitations or restrictions on the types of activities that can be registered under Section 8 of the Companies Act?'
# '11. What are the specific requirements for filing the memorandum and articles of a company under Section 8 of the Companies Act?'
# '12. Who can make the declaration stating that all the requirements of the Companies Act and the rules made thereunder have been complied with for the registration of a company under Section 8?'
# '13. What is the process for paying the necessary fees for the registration of a company under Section 8 of the Companies Act?'
# '14. Are there any additional qualifications or criteria that need to be met in order to register a company under Section 8, which are not mentioned in the provided context?'
# '15. What privileges and obligations do limited companies registered under Section 8 of the Companies Act enjoy and are subject to?'
# '16. Can the Central Government approve alterations to the memorandum or articles of a company registered under Section 8 of the Companies Act? If so, what is the process for obtaining this approval?'
# '17. What authority does the Central Government have in terms of directing the preparation of seals for the authentication of registration-related documents for companies registered under Section 8 of the Companies Act?'
# '18. How does the Central Government appoint Registrars and other officers for the registration of companies under Section 8 of the Companies Act? Are there any specific qualifications or criteria for these appointments?'
# '19. Can companies with charitable objectives alter their articles through a special resolution under Section 14 of the Companies Act?'
# '20. What is the timeframe within which any alteration made under Section 8 must be registered with the Registrar to have legal effect?'
# '21. Are there any specific requirements or qualifications for companies with charitable objectives to convert from a private company to a public company or vice versa under Section 14 of the Companies Act?'
# '22. How does the alteration process for companies with charitable objectives differ from other companies under Section 14 of the Companies Act?'
# '23. Can a company registered under Section 8 of the Companies Act contribute to funds approved by the Central Government for purposes other than national defense?'
# '24. What are some examples of funds set up by the Central Government that a Section 8 company can contribute to?'
# '25. Does Section 183 of the Companies Act override any other provision in the Act or in the company's memorandum, articles, or any other instrument relating to the company when it comes to making contributions to approved funds?'
# '26. What are some examples of purposes or causes, other than national defense, for which a Section 8 company can make contributions to funds approved by the Central Government?'
# ** 🤔 Next Questions I must ask: **
#  8 Can a company registered under Section 8 of the Companies Act contribute to funds set up by the Central Government other than the Prime Minister's National Relief Fund?
# ** Answer **
#  Yes, a company registered under Section 8 of the Companies Act can contribute to funds set up by the Central Government other than the Prime Minister's National Relief Fund. Section 183 of the Companies Act allows the Board of Directors or any person or authority exercising the powers of the Board of Directors to contribute to the National Defence Fund or any other Fund approved by the Central Government for the purpose of national defence. This provision overrides any other provision in the Act or in the company's memorandum, articles, or any other instrument relating to the company. Therefore, a Section 8 company can make contributions to funds approved by the Central Government for purposes other than national defence, such as welfare, religion, charity, or protection of the environment.
#
#  ✔✔  Max Iterations Reached. Compiling the results ...
#
# Section 8 of the Companies Act, 2013 deals with the formulation of companies with charitable objects. It allows for the registration of companies that have charitable or socially beneficial objectives. The section states that if a person or an association of persons intends to register as a limited company under this Act and has the objective of promoting commerce, art, science, sports, education, research, social welfare, religion, charity, protection of environment, or any other similar object, they can do so with the satisfaction of the Central Government.
#
# The role of the Central Government in the registration process of companies with charitable objects under Section 8 is to determine whether the person or association of persons seeking registration meets the criteria for promoting the specified objects. If it is proved to the satisfaction of the Central Government that the person or association of persons meets these criteria, the Central Government will register them as a company under Section 8. The company registered under this section will enjoy all the privileges and be subject to all the obligations of limited companies. The Central Government also has the authority to approve any alterations to the company's memorandum or articles and to direct the preparation of seals for the authentication of registration-related documents. The Central Government may appoint Registrars and other officers for the registration of companies and may provide resources for the administration of the registration process.
#
# Section 8 of the Companies Act explains the formation of companies with charitable objects or purposes. It provides guidelines and regulations for companies that are established for charitable or philanthropic purposes. The section outlines the requirements and procedures for incorporating such companies and the effect of registration. It also covers the alteration of memorandum and articles for these companies. While the Act does not specifically mention the alteration of memorandum and articles for companies with charitable objectives, Section 14 of the Act allows a company, by a special resolution, to alter its articles. This suggests that companies with charitable objectives can also alter their articles through a special resolution. Any alteration made under this section must be registered with the Registrar within 30 days to have legal effect.
#
# Some examples of charitable objects or purposes that can be registered under Section 8 of the Companies Act include the promotion of commerce, art, science, sports, education, research, social welfare, religion, charity, protection of the environment, and any other similar object. Additionally, activities such as eradicating extreme hunger and poverty, promoting education, gender equality, and women empowerment, reducing child mortality and improving maternal health, combating diseases like HIV/AIDS and malaria, ensuring environmental sustainability, enhancing vocational skills, and contributing to the Prime Minister's National Relief Fund or any other fund set up by the Central Government can be included in a company's Corporate Social Responsibility Policies.
#
# Based on the information provided in the context, there are specific requirements and qualifications that a person or association of persons must meet in order to register a company under Section 8 of the Companies Act. These requirements include filing the memorandum and articles of the company, signed by all the subscribers to the memorandum, with the Registrar. Additionally, a declaration must be made by an advocate, chartered accountant, cost accountant, or company secretary in practice, who is engaged in the formation of the company, along with a person named in the articles as a director, manager, or secretary of the company, stating that all the requirements of the Companies Act and the rules made thereunder have been complied with. The company must also pay the necessary fees for registration. However, the specific qualifications or criteria for registering a company under Section 8 are not mentioned in the provided context.
#
# In conclusion, Section 8 of the Companies Act, 2013 allows for the registration of companies with charitable or socially beneficial objectives. The Central Government plays a crucial role in the registration process, determining whether the objectives meet the specified criteria. The section also provides guidelines for the formation of such companies, including the filing of memorandum and articles, alteration of articles through special resolution, and compliance with the Companies Act and rules. Companies registered under Section 8 can contribute to funds approved by the Central Government for purposes such as welfare, religion, charity, or protection of the environment.
