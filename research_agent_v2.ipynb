# %% [markdown]
# # Create a Research Agent

# %% [markdown]
# This is a concept agent that is inspired by my process of researching on a subject. <br>
# I also took some inspiration from BabyAGI (without tools) implementation

# %%
from dotenv import load_dotenv

load_dotenv("./.env")
import uuid
import os
from langchain.chat_models import ChatOpenAI
from langchain.embeddings import OpenAIEmbeddings
from langchain.prompts import PromptTemplate
from yachalk import chalk

# %%
text_embedding_model = "text-embedding-ada-002"
embeddings = OpenAIEmbeddings(model=text_embedding_model)

# %% [markdown]
# ## Set up the vector store

# %%
use_localdb = False

SUPABASE_PASSWORD = os.environ["SUPABASE_PASSWORD"]
SUPABASE_DBUSER = os.environ["SUPABASE_DBUSER"]
SUPABASE_DATABASE = os.environ["SUPABASE_DATABASE"]
supabasedb_string = f"postgresql://{SUPABASE_DBUSER}:{SUPABASE_PASSWORD}@db.doxggeyqopdnxfhseufq.supabase.co:5432/{SUPABASE_DATABASE}"

PGVECTOR_USER = os.environ["PGVECTOR_USER"]
PGVECTOR_PASSWORD = os.environ["PGVECTOR_PASSWORD"]
PGVECTOR_DATABASE = os.environ["PGVECTOR_DATABASE"]
localdb_string = f"postgresql://{PGVECTOR_USER}:{PGVECTOR_PASSWORD}@localhost:5432/{PGVECTOR_DATABASE}"

connection_string = localdb_string if use_localdb else supabasedb_string

# %%
## Law store
from langchain.vectorstores import PGVector

law_compilation_store = PGVector(
    collection_name="law_compilation",
    connection_string=connection_string,
    embedding_function=embeddings,
)

## Mahabharata Store
mahabharata_store = PGVector(
    collection_name="mahabharat_combined_text",
    connection_string=connection_string,
    embedding_function=embeddings,
)

# %% [markdown]
# ### Supabase vector store for storing runs
#
# The supabase client here is not used as a vector store.
# I am only using it to save the runs data.
# You can remove it if you dont need it.

# %%
from supabase.client import Client, create_client
from langchain.vectorstores import SupabaseVectorStore

supabase_url = os.environ.get("SUPABASE_URL")
supabase_key = os.environ.get("SUPABASE_SERVICE_KEY")
supabase: Client = create_client(supabase_url, supabase_key)

runs_store = SupabaseVectorStore(
    embedding=embeddings, client=supabase, table_name="runs", query_name="match_runs"
)

# ## Testing store
# run_id = str(uuid.uuid4())
# runs_store.add_texts(texts=["testing the store"], metadatas=[{"key": "value"}], ids=[run_id])
# matched_docs = runs_store.similarity_search_with_relevance_scores("testing store", 1)
# matched_docs

# %% [markdown]
# ### Import Chains

# %% [markdown]
# #### Question creator
#
# Generate new questions based on
#
# -   `question` - Original question. This is important so that the pertinence to the original question is always maintained. Or else the context can diverge quickly into impertinent results.
# -   `unanswered_questions`: So that the new questions do not overlap with the old ones.
# -   `context`: The answer to the last question.
# -   `num_questions`: Configurable hyper parameter.
# -   `start_id`: This is passed so that the ids of the newly generated question do overlap with the current list.
#
# ---
#
# #### Most pertinent Question chain
#
# Pick the most pertinent question out of the given list of questions <br>
# I am not using any additional context other than the `original_question` for decising the pertinence.
#
# ---
#
# #### Retrieval QA
#
# This chain is used to answer the intermediate questions. The idea is to generate succinct answers which can be used as notes to finally answer the original question
#
# ---
#
# #### Result Analyser
#
# Not using this right now. I am not able to get this piece working well. So currently I will just run the agent for a fixed number of iterations and then compile the answer.

# %%
## Import all the chains.
from chains_v2.create_questions import QuestionCreationChain
from chains_v2.most_pertinent_question import MostPertinentQuestion
from chains_v2.retrieval_qa import retrieval_qa
from chains_v2.research_compiler import research_compiler
from chains_v2.question_atomizer import QuestionAtomizer

## Model with parameters
gpt3t = "gpt-3.5-turbo"


def language_model(
    model_name: str = gpt3t, temperature: float = 0, verbose: bool = False
):
    llm = ChatOpenAI(model_name=model_name, temperature=temperature, verbose=verbose)
    return llm

# %% [markdown]
# ### Importing Question helpers

# %%
from helpers.response_helpers import result2QuestionsList
from helpers.response_helpers import qStr2Dict
from helpers.questions_helper import getAnsweredQuestions
from helpers.questions_helper import getUnansweredQuestions
from helpers.questions_helper import getSubQuestions
from helpers.questions_helper import getHopQuestions
from helpers.questions_helper import getLastQuestionId
from helpers.questions_helper import markAnswered
from helpers.questions_helper import getQuestionById

# %% [markdown]
# # The Research Agent

# %% [markdown]
# Question Data Schema
#
# ```
#   Question: {
#     id: int,
#     question: string,
#     type: 'subquestion' | 'hops',
#     status: 'answered' | 'unanswered',
#     answer: string,
#     documents: []
#   }
# ```

# %%
run_id = str(uuid.uuid4())
scratchpad = {
    "original_question": "Exploain section 8 of the companies act?",
    "questions": [],  # list of type Question
}
verbose = False
max_iterations = 5
current_iteration = 0
num_atomistic_questions = 2
num_questions_per_iteration = 4
question_atomizer_temperature = 0
question_creation_temperature = 0.4
question_prioritisation_temperature = 0
qa_temperature = 0
analyser_temperature = 0
intermediate_answers_length = 200
answer_length = 500
store = law_compilation_store

## ---- The researcher ----- ##

## Step 0. Prepare the initial set of questions
question_atomizer = QuestionAtomizer.from_llm(
    llm=language_model(temperature=question_atomizer_temperature), verbose=verbose
)

atomized_questions_response = question_atomizer.run(
    question=scratchpad["original_question"],
    num_questions=num_atomistic_questions,
)

scratchpad["questions"] += result2QuestionsList(
    question_response=atomized_questions_response,
    type="subquestion",
    status="unanswered",
)

for q in scratchpad["questions"]:
    q["answer"], q["documents"] = retrieval_qa(
        llm=language_model(temperature=qa_temperature, verbose=verbose),
        retriever=store.as_retriever(
            search_type="mmr", search_kwargs={"k": 5, "fetch_k": 10}
        ),
        question=q["question"],
        answer_length=intermediate_answers_length,
        verbose=verbose,
    )
    q["status"] = "answered"
    print(chalk.magenta.bold(f"** Sub Question **\n{q['question']}\n{q['answer']}\n"))

current_context = "".join(
    f"\n{q['id']}. {q['question']}\n{q['answer']}\n" for q in scratchpad["questions"]
)


verbose = False
while True:
    current_iteration += 1
    print(
        chalk.bg_yellow_bright.black.bold(f"\n   Iteration - {current_iteration}  ▷▶  \n")
    )

    # STEP 1: create questions
    start_id = getLastQuestionId(scratchpad["questions"]) + 1
    question_creation_chain = QuestionCreationChain.from_llm(
        language_model(temperature=question_creation_temperature), verbose=verbose
    )
    questions_response = question_creation_chain.run(
        question=scratchpad["original_question"],
        context=current_context,
        previous_questions=[
            "".join(f"\n{q['question']}") for q in scratchpad["questions"]
        ],
        num_questions=num_questions_per_iteration,
        start_id=start_id,
    )
    scratchpad["questions"] += result2QuestionsList(
        question_response=questions_response,
        type="hop",
        status="unanswered",
    )

    # STEP 2: Choose question for current iteration
    unanswered = getUnansweredQuestions(scratchpad["questions"])
    unanswered_questions_prompt = (
        "[" + "".join([f"\n{q['id']}. {q['question']}" for q in unanswered]) + "]"
    )
    print(
        chalk.cyan_bright("** Unanswered Questions **"),
        chalk.cyan("".join([f"\n'{q['id']}. {q['question']}'" for q in unanswered])),
    )
    most_pertinent_question = MostPertinentQuestion.from_llm(
        language_model(temperature=question_creation_temperature), verbose=verbose
    )
    response = most_pertinent_question.run(
        original_question=scratchpad["original_question"],
        unanswered_questions=unanswered_questions_prompt,
    )

    current_question_dict = qStr2Dict(question=response)
    current_question_id = current_question_dict["id"]

    current_question = getQuestionById(scratchpad["questions"], current_question_id)

    print(
        chalk.magenta.bold("** 🤔 Next Questions I must ask: **\n"),
        chalk.magenta(current_question_id),
        chalk.magenta(current_question["question"]),
    )

    # STEP 3: Answer the question
    current_question["answer"], current_question["documents"] = retrieval_qa(
        llm=language_model(temperature=qa_temperature, verbose=verbose),
        retriever=store.as_retriever(
            search_type="mmr", search_kwargs={"k": 5, "fetch_k": 10}
        ),
        question=current_question["question"],
        answer_length=intermediate_answers_length,
        verbose=verbose,
    )
    markAnswered(scratchpad["questions"], current_question_id)

    print(
        chalk.yellow_bright.bold("** Answer **\n"),
        chalk.yellow_bright(current_question["answer"]),
    )

    current_context = current_question["answer"]

    if current_iteration > max_iterations:
        print(
            chalk.bg_yellow_bright.black.bold(
                "\n ✔✔  Max Iterations Reached. Compiling the results ...    \n"
            )
        )
        break


## STEP 4: Compile the research
answered_questions = getAnsweredQuestions(scratchpad["questions"])
answered_questions_prompt = (
    "["
    + "".join(
        [
            f"{{ Question: {q['question']}, Answer: {q['answer']} }}"
            for q in answered_questions
        ]
    )
    + "]"
)
result = research_compiler(
    llm=language_model(temperature=qa_temperature, verbose=verbose),
    question=scratchpad["original_question"],
    notes=answered_questions_prompt,
    answer_length=answer_length,
    verbose=verbose,
)

print(chalk.italic.white_bright((result["text"])))

# current_question = response
## Collect initial document with semantic search.
# Out:
# ** Sub Question **
# What is section 8 of the Companies Act?
# Section 8 of the Companies Act, 2013 deals with the formulation of companies with charitable objects. It states that if a person or an association of persons intends to register as a limited company under this Act and has the objective of promoting commerce, art, science, sports, education, research, social welfare, religion, charity, protection of environment, or any other similar object, they can do so with the satisfaction of the Central Government. This section allows for the registration of companies that have charitable or socially beneficial objectives.
#
# ** Sub Question **
# What does section 8 of the Companies Act explain?
# Section 8 of the Companies Act explains the formation of companies with charitable objects or for promoting commerce, art, science, sports, education, research, social welfare, religion, charity, protection of the environment, or any other similar object. This section provides guidelines for the incorporation and registration of such companies and specifies the requirements and procedures they need to follow. It also outlines the effect of registration and the powers and limitations of companies formed under this section.
#
#
#    Iteration - 1  ▷▶
#
# ** Unanswered Questions **
# '3. What are the specific objectives or purposes that a company can have in order to qualify for registration under section 8 of the Companies Act?'
# '4. How does the Central Government determine whether a company's objectives meet the criteria for registration under section 8 of the Companies Act?'
# '5. What are the requirements and procedures that companies need to follow in order to be incorporated and registered under section 8 of the Companies Act?'
# '6. Can companies formed under section 8 of the Companies Act have any limitations or restrictions on their powers? If so, what are they?'
# ** 🤔 Next Questions I must ask: **
#  3 What are the specific objectives or purposes that a company can have in order to qualify for registration under section 8 of the Companies Act?
# ** Answer **
#  The specific objectives or purposes that a company can have in order to qualify for registration under section 8 of the Companies Act are as follows:
# - Promotion of commerce, art, science, sports, education, research, social welfare, religion, charity, protection of environment, or any other similar object.
# - The company must have a name that includes "Limited" or "Private Limited".
# - The registered office of the company should be situated in a specific state.
# - The liability of the member(s) should be limited.
# - Every member of the company must undertake to contribute to the assets of the company in the event of its winding up, for payment of debts and liabilities.
# - The company must ensure that secured creditors have consented to or given their no objection to the company's registration.
# - The company must publish advertisements in newspapers seeking objections to its registration.
# - The company must file an affidavit from all members or partners stating that necessary documents or papers will be submitted for dissolution as a partnership firm.
# - The company must file the memorandum and articles of association, along with a declaration by professionals engaged in the formation of the company, stating compliance with the Act and rules.
#
#    Iteration - 2  ▷▶
#
# ** Unanswered Questions **
# '4. How does the Central Government determine whether a company's objectives meet the criteria for registration under section 8 of the Companies Act?'
# '5. What are the requirements and procedures that companies need to follow in order to be incorporated and registered under section 8 of the Companies Act?'
# '6. Can companies formed under section 8 of the Companies Act have any limitations or restrictions on their powers? If so, what are they?'
# '7. What are the specific criteria for a company's name to qualify for registration under section 8 of the Companies Act?'
# '8. What are the requirements for the registered office of a company to be situated in a specific state under section 8 of the Companies Act?'
# '9. How does the liability of the member(s) of a company need to be limited in order to qualify for registration under section 8 of the Companies Act?'
# '10. What is the process for obtaining consent or no objection from secured creditors for a company's registration under section 8 of the Companies Act?'
# ** 🤔 Next Questions I must ask: **
#  4 How does the Central Government determine whether a company's objectives meet the criteria for registration under section 8 of the Companies Act?
# ** Answer **
#  The Central Government determines whether a company's objectives meet the criteria for registration under section 8 of the Companies Act by considering the objects stated in the company's registration proposal. If the company's objects include the promotion of commerce, art, science, sports, education, research, social welfare, religion, charity, protection of environment, or any other similar object, it may be eligible for registration under section 8. The Central Government may appoint inspectors to investigate the company's affairs and report on them. If a company registered under section 8 contravenes the requirements of this section, conducts its affairs fraudulently or in a manner violative of its objects or prejudicial to public interest, the Central Government may revoke its license and direct the company to convert its status and change its name to add the word "Limited" or "Private Limited" as applicable.
#
#    Iteration - 3  ▷▶
#
# ** Unanswered Questions **
# '5. What are the requirements and procedures that companies need to follow in order to be incorporated and registered under section 8 of the Companies Act?'
# '6. Can companies formed under section 8 of the Companies Act have any limitations or restrictions on their powers? If so, what are they?'
# '7. What are the specific criteria for a company's name to qualify for registration under section 8 of the Companies Act?'
# '8. What are the requirements for the registered office of a company to be situated in a specific state under section 8 of the Companies Act?'
# '9. How does the liability of the member(s) of a company need to be limited in order to qualify for registration under section 8 of the Companies Act?'
# '10. What is the process for obtaining consent or no objection from secured creditors for a company's registration under section 8 of the Companies Act?'
# '11. How does the Central Government determine if a company's objectives meet the criteria for registration under section 8 of the Companies Act based on the objects stated in the registration proposal?'
# '12. What are the potential consequences for a company registered under section 8 if it conducts its affairs fraudulently or in a manner violative of its objects or prejudicial to public interest?'
# '13. Can the Central Government appoint inspectors to investigate the affairs of a company registered under section 8? If so, what is the purpose of such investigations?'
# '14. In case a company registered under section 8 contravenes the requirements of this section, what actions can the Central Government take to address the violation and ensure compliance?'
# ** 🤔 Next Questions I must ask: **
#  5 What are the requirements and procedures that companies need to follow in order to be incorporated and registered under section 8 of the Companies Act?
# ** Answer **
#  Context not sufficient.
#
#    Iteration - 4  ▷▶
#
# ** Unanswered Questions **
# '6. Can companies formed under section 8 of the Companies Act have any limitations or restrictions on their powers? If so, what are they?'
# '7. What are the specific criteria for a company's name to qualify for registration under section 8 of the Companies Act?'
# '8. What are the requirements for the registered office of a company to be situated in a specific state under section 8 of the Companies Act?'
# '9. How does the liability of the member(s) of a company need to be limited in order to qualify for registration under section 8 of the Companies Act?'
# '10. What is the process for obtaining consent or no objection from secured creditors for a company's registration under section 8 of the Companies Act?'
# '11. How does the Central Government determine if a company's objectives meet the criteria for registration under section 8 of the Companies Act based on the objects stated in the registration proposal?'
# '12. What are the potential consequences for a company registered under section 8 if it conducts its affairs fraudulently or in a manner violative of its objects or prejudicial to public interest?'
# '13. Can the Central Government appoint inspectors to investigate the affairs of a company registered under section 8? If so, what is the purpose of such investigations?'
# '14. In case a company registered under section 8 contravenes the requirements of this section, what actions can the Central Government take to address the violation and ensure compliance?'
# '15. Is the context provided in the new text sufficient to understand the requirements and procedures of section 8 of the Companies Act?'
# '16. Does the new text provide any information about the limitations or restrictions on the powers of companies formed under section 8 of the Companies Act?'
# '17. Can the new text shed light on the specific criteria for a company's name to qualify for registration under section 8 of the Companies Act?'
# '18. Does the new text mention any potential consequences for a company registered under section 8 if it conducts its affairs fraudulently or in a manner violative of its objects or prejudicial to public interest?'
# ** 🤔 Next Questions I must ask: **
#  6 Can companies formed under section 8 of the Companies Act have any limitations or restrictions on their powers? If so, what are they?
# ** Answer **
#  Based on the provided context, companies formed under section 8 of the Companies Act can have limitations or restrictions on their powers. These limitations or restrictions are mentioned in clauses (b) and (c) of sub-section (1) of the Act. Clause (b) states that an unlimited company, upon registration as a limited company, can increase its share capital and provide that a portion of the share capital cannot be called-up except in the event of winding up. Clause (c) states that a limited company can determine that a portion of its share capital cannot be called-up except in the event of winding up. These limitations and restrictions apply regardless of any other laws or instruments regulating the company. However, it is important to note that the context provided is not sufficient to provide a comprehensive answer and further information may be required.
#
#    Iteration - 5  ▷▶
#
# ** Unanswered Questions **
# '7. What are the specific criteria for a company's name to qualify for registration under section 8 of the Companies Act?'
# '8. What are the requirements for the registered office of a company to be situated in a specific state under section 8 of the Companies Act?'
# '9. How does the liability of the member(s) of a company need to be limited in order to qualify for registration under section 8 of the Companies Act?'
# '10. What is the process for obtaining consent or no objection from secured creditors for a company's registration under section 8 of the Companies Act?'
# '11. How does the Central Government determine if a company's objectives meet the criteria for registration under section 8 of the Companies Act based on the objects stated in the registration proposal?'
# '12. What are the potential consequences for a company registered under section 8 if it conducts its affairs fraudulently or in a manner violative of its objects or prejudicial to public interest?'
# '13. Can the Central Government appoint inspectors to investigate the affairs of a company registered under section 8? If so, what is the purpose of such investigations?'
# '14. In case a company registered under section 8 contravenes the requirements of this section, what actions can the Central Government take to address the violation and ensure compliance?'
# '15. Is the context provided in the new text sufficient to understand the requirements and procedures of section 8 of the Companies Act?'
# '16. Does the new text provide any information about the limitations or restrictions on the powers of companies formed under section 8 of the Companies Act?'
# '17. Can the new text shed light on the specific criteria for a company's name to qualify for registration under section 8 of the Companies Act?'
# '18. Does the new text mention any potential consequences for a company registered under section 8 if it conducts its affairs fraudulently or in a manner violative of its objects or prejudicial to public interest?'
# '19. What are the limitations or restrictions on the powers of companies formed under section 8 of the Companies Act as mentioned in clauses (b) and (c) of sub-section (1) of the Act?'
# '20. How does clause (b) of sub-section (1) of the Companies Act explain the ability of an unlimited company to increase its share capital and restrict the calling-up of a portion of the share capital except in the event of winding up?'
# '21. Can a limited company determine that a portion of its share capital cannot be called-up except in the event of winding up? If so, how does clause (c) of sub-section (1) of the Companies Act explain this provision?'
# '22. Do the limitations and restrictions mentioned in clauses (b) and (c) of sub-section (1) of the Companies Act apply to all companies formed under section 8, regardless of any other laws or instruments regulating the company?'
# ** 🤔 Next Questions I must ask: **
#  8 What are the requirements for the registered office of a company to be situated in a specific state under section 8 of the Companies Act?
# ** Answer **
#  Based on the information provided in the context, the requirements for the registered office of a company to be situated in a specific state under section 8 of the Companies Act are as follows:
#
# 1. The company must have a registered office capable of receiving and acknowledging all communications and notices addressed to it.
# 2. The company must furnish verification of its registered office to the Registrar within 30 days of its incorporation.
# 3. The company must paint or affix its name and the address of its registered office on the outside of every office or place where its business is carried on.
# 4. The registered office of an existing company cannot be changed outside the local limits of any city, town, or village where it is situated at the commencement of the Act or where it may be situated later by virtue of a special resolution passed by the company.
# 5. The registered office of any other company cannot be changed outside the local limits of any city, town, or village where it is first situated or where it may be situated later by virtue of a special resolution passed by the company.
# 6. No company can change the place of its registered office from the jurisdiction of one Registrar to the jurisdiction of another Registrar within the same state unless such change is confirmed by a special resolution and a report referred to in section 394(1) of the Act.
#
# In summary, the registered office of a company must be capable of receiving communications, must be verified with the Registrar, and must comply with the restrictions on changing its location.
#
#    Iteration - 6  ▷▶
#
# ** Unanswered Questions **
# '7. What are the specific criteria for a company's name to qualify for registration under section 8 of the Companies Act?'
# '9. How does the liability of the member(s) of a company need to be limited in order to qualify for registration under section 8 of the Companies Act?'
# '10. What is the process for obtaining consent or no objection from secured creditors for a company's registration under section 8 of the Companies Act?'
# '11. How does the Central Government determine if a company's objectives meet the criteria for registration under section 8 of the Companies Act based on the objects stated in the registration proposal?'
# '12. What are the potential consequences for a company registered under section 8 if it conducts its affairs fraudulently or in a manner violative of its objects or prejudicial to public interest?'
# '13. Can the Central Government appoint inspectors to investigate the affairs of a company registered under section 8? If so, what is the purpose of such investigations?'
# '14. In case a company registered under section 8 contravenes the requirements of this section, what actions can the Central Government take to address the violation and ensure compliance?'
# '15. Is the context provided in the new text sufficient to understand the requirements and procedures of section 8 of the Companies Act?'
# '16. Does the new text provide any information about the limitations or restrictions on the powers of companies formed under section 8 of the Companies Act?'
# '17. Can the new text shed light on the specific criteria for a company's name to qualify for registration under section 8 of the Companies Act?'
# '18. Does the new text mention any potential consequences for a company registered under section 8 if it conducts its affairs fraudulently or in a manner violative of its objects or prejudicial to public interest?'
# '19. What are the limitations or restrictions on the powers of companies formed under section 8 of the Companies Act as mentioned in clauses (b) and (c) of sub-section (1) of the Act?'
# '20. How does clause (b) of sub-section (1) of the Companies Act explain the ability of an unlimited company to increase its share capital and restrict the calling-up of a portion of the share capital except in the event of winding up?'
# '21. Can a limited company determine that a portion of its share capital cannot be called-up except in the event of winding up? If so, how does clause (c) of sub-section (1) of the Companies Act explain this provision?'
# '22. Do the limitations and restrictions mentioned in clauses (b) and (c) of sub-section (1) of the Companies Act apply to all companies formed under section 8, regardless of any other laws or instruments regulating the company?'
# '23. What are the consequences for a company if it fails to furnish verification of its registered office to the Registrar within 30 days of incorporation under section 8 of the Companies Act?'
# '24. Can a company change the location of its registered office outside the local limits of any city, town, or village where it is situated at the commencement of the Act or where it may be situated later by virtue of a special resolution passed by the company under section 8 of the Companies Act?'
# '25. What is the significance of a special resolution in changing the place of a company's registered office from the jurisdiction of one Registrar to the jurisdiction of another Registrar within the same state under section 8 of the Companies Act?'
# '26. Are there any additional requirements or restrictions for the registered office of a company under section 8 of the Companies Act that are not mentioned in the provided text?'
# ** 🤔 Next Questions I must ask: **
#  8 What are the requirements for the registered office of a company to be situated in a specific state under section 8 of the Companies Act?
# ** Answer **
#  The requirements for the registered office of a company to be situated in a specific state under section 8 of the Companies Act are as follows:
#
# 1. The company must have a registered office capable of receiving and acknowledging all communications and notices addressed to it.
# 2. The company must furnish verification of its registered office to the Registrar within 30 days of its incorporation.
# 3. The company must paint or affix its name and the address of its registered office on the outside of every office or place where its business is carried on.
# 4. The registered office of an existing company cannot be changed outside the local limits of any city, town, or village where it is situated at the commencement of the Act or where it may be situated later by virtue of a special resolution passed by the company.
# 5. The registered office of any other company cannot be changed outside the local limits of any city, town, or village where it is first situated or where it may be situated later by virtue of a special resolution passed by the company.
# 6. No company can change the place of its registered office from the jurisdiction of one Registrar to the jurisdiction of another Registrar within the same state unless such change is confirmed by the branch office to the company at its registered office or the other place referred to in subsection (1).
#
#  ✔✔  Max Iterations Reached. Compiling the results ...
#
# Section 8 of the Companies Act, 2013 deals with the formulation of companies with charitable objects. It allows for the registration of companies that have charitable or socially beneficial objectives. The section specifies the requirements and procedures that these companies need to follow in order to be incorporated and registered.
#
# To qualify for registration under section 8, a company must have the objective of promoting commerce, art, science, sports, education, research, social welfare, religion, charity, protection of environment, or any other similar object. The company must also have a name that includes "Limited" or "Private Limited" and its registered office should be situated in a specific state.
#
# The liability of the member(s) of the company should be limited, and every member must undertake to contribute to the assets of the company in the event of its winding up, for payment of debts and liabilities. The company must ensure that secured creditors have consented to or given their no objection to the company's registration.
#
# In order to be incorporated and registered under section 8, the company must follow certain procedures. It must publish advertisements in newspapers seeking objections to its registration. The company must file an affidavit from all members or partners stating that necessary documents or papers will be submitted for dissolution as a partnership firm. The company must also file the memorandum and articles of association, along with a declaration by professionals engaged in the formation of the company, stating compliance with the Act and rules.
#
# The Central Government determines whether a company's objectives meet the criteria for registration under section 8 by considering the objects stated in the company's registration proposal. If the company's objects include the promotion of commerce, art, science, sports, education, research, social welfare, religion, charity, protection of environment, or any other similar object, it may be eligible for registration under section 8. The Central Government may appoint inspectors to investigate the company's affairs and report on them.
#
# Companies formed under section 8 of the Companies Act can have limitations or restrictions on their powers. Clauses (b) and (c) of sub-section (1) of the Act mention these limitations or restrictions. An unlimited company, upon registration as a limited company, can increase its share capital and provide that a portion of the share capital cannot be called-up except in the event of winding up. A limited company can determine that a portion of its share capital cannot be called-up except in the event of winding up. These limitations and restrictions apply regardless of any other laws or instruments regulating the company.
#
# The requirements for the registered office of a company to be situated in a specific state under section 8 of the Companies Act are as follows: the company must have a registered office capable of receiving and acknowledging all communications and notices addressed to it. The company must furnish verification of its registered office to the Registrar within 30 days of its incorporation. The company must also paint or affix its name and the address of its registered office on the outside of every office or place where its business is carried on.
#
# In conclusion, section 8 of the Companies Act, 2013 provides guidelines for the incorporation and registration of companies with charitable objects or for promoting various beneficial objectives. It outlines the requirements and procedures that these companies need to follow, including the specific objectives they must have, the limitations or restrictions on their powers, and the requirements for their registered office.
