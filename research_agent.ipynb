# %% [markdown]
# # Create a Research Agent

# %% [markdown]
# This is a concept agent that is inspired by my process of researching on a subject. <br>
# I also took some inspiration from BabyAGI (without tools) implementation

# %%
from dotenv import load_dotenv
load_dotenv('./.env') 
import uuid
import os
from langchain.chat_models import ChatOpenAI
from langchain.embeddings import OpenAIEmbeddings
from langchain.prompts import PromptTemplate

# %%
text_embedding_model = "text-embedding-ada-002"
gpt3t = "gpt-3.5-turbo"
gpt4 = "gpt-4"

embeddings = OpenAIEmbeddings(model=text_embedding_model)

# %% [markdown]
# ## Set up the vector store

# %%
use_localdb = True

SUPABASE_PASSWORD = os.environ['SUPABASE_PASSWORD']
SUPABASE_DBUSER = os.environ['SUPABASE_DBUSER']
SUPABASE_DATABASE = os.environ['SUPABASE_DATABASE']
supabasedb_string = f"postgresql://{SUPABASE_DBUSER}:{SUPABASE_PASSWORD}@db.doxggeyqopdnxfhseufq.supabase.co:5432/{SUPABASE_DATABASE}"

PGVECTOR_USER = os.environ['PGVECTOR_USER']
PGVECTOR_PASSWORD = os.environ['PGVECTOR_PASSWORD']
PGVECTOR_DATABASE = os.environ['PGVECTOR_DATABASE']
localdb_string = f"postgresql://{PGVECTOR_USER}:{PGVECTOR_PASSWORD}@localhost:5432/{PGVECTOR_DATABASE}"

connection_string = localdb_string if use_localdb else supabasedb_string

# %% [markdown]
# ### Main text store

# %%
from langchain.vectorstores import PGVector

combined_text_store = PGVector(
    collection_name='mahabharat_combined_text',
    connection_string=connection_string,
    embedding_function=embeddings,
)
print(type(combined_text_store))
# Out:
# <class 'langchain.vectorstores.pgvector.PGVector'>

# %% [markdown]
# ### Supabase vector store for storing runs
#
# The supabase client here is not used as a vector store.
# I am only using it to save the runs data.
# You can remove it if you dont need it.

# %%
from supabase.client import Client, create_client
from langchain.vectorstores import SupabaseVectorStore

supabase_url = os.environ.get("SUPABASE_URL")
supabase_key = os.environ.get("SUPABASE_SERVICE_KEY")
supabase: Client = create_client(supabase_url, supabase_key)

runs_store = SupabaseVectorStore(embedding=embeddings, client=supabase, table_name='runs',query_name="match_runs")

# ## Testing store
# run_id = str(uuid.uuid4())
# runs_store.add_texts(texts=["testing the store"], metadatas=[{"key": "value"}], ids=[run_id])
# matched_docs = runs_store.similarity_search_with_relevance_scores("testing store", 1)
# matched_docs

# %% [markdown]
# ### Helper Function for converting question string to list of questions

# %%
def split2Dict(question):
    question = question.strip().split(".", 1)
    question_dict = {question[0].strip(): question[-1].strip()}
    return question_dict


def result2DictOfQuestions(result: str):
    questions = result.split("\n")
    qdict = {}
    for q in questions:
        qdict = {**qdict, **split2Dict(q)}
    return qdict

# %% [markdown]
# ## Import Chains

# %% [markdown]
# #### Question creator
# Generate new questions based on
# - `question` - Original question. This is important so that the pertinence to the original question is always maintained. Or else the context can diverge quickly into impertinent results.
# - `unanswered_questions`: So that the new questions do not overlap with the old ones.
# - `context`: The document found during the current run. So the questions are derived from the fresh information based on the current question being asked.
# - `num_questions`: Configurable hyper parameter.
# - `start_id`: This is passed so that the ids of the newly generated question do overlap with the current list.
#
# ---
# #### Most pertinent Question chain
# Pick the most pertinent question out of the given list of questions <br>
# I am not using any additional context other than the `original_question` for decising the pertinence.
#
# ---
# #### Retrieval QA
# This chain is used to answer the intermediate questions. The idea is to generate succinct answers which can be used as notes to finally answer the original question
#
# ---
# #### Result Analyser
# Not using this right now. I am not able to get this piece working well. So currently I will just run the agent for a fixed number of iterations and then compile the answer.

# %%
## Import all the chains. 
from chains.create_questions import QuestionCreationChain 
from chains.most_pertinent_question import MostPertinentQuestion
from chains.retrieval_qa import retrieval_qa
from chains.research_compiler import research_compiler

## Model with parameters
def language_model(model_name: str = gpt3t, temperature: float = 0, verbose: bool = False):
    llm = ChatOpenAI(model_name=model_name, temperature=temperature)
    return llm

# %% [markdown]
# # The Research Agent
#
# This is the final research Agent.

# %%
## First create a run id. 
run_id = str(uuid.uuid4())

## Define scratchpad for keeping the run data
scratchpad = {
    'original_question': "why did Mahabharata war happen?",
    'unanswered_questions': {},
    'answerpad': [],
    'notes': [],
    'current_documents': [],
    'documents': [],
    'answered_questions': [],
}
verbose = False
first_run = True
max_iterations = 6
current_iteration = 0
num_questions_per_iteration = 3
question_creation_temperature = 0.2
question_prioritisation_temperature = 0.2
analyser_temperature = 0
store = combined_text_store
current_question_id = None


## ---- The researcher -----
while True: 
    current_iteration += 1

    print("\033[91m\033[1m" + f"\n ------  Iteration {current_iteration} ------- \n" + "\033[0m\033[0m")
    if current_iteration >= max_iterations:
        print("\033[91m\033[1m" + f"\n ------ Max iterations reached." + "\033[0m\033[0m")
        break
    
    ## 1. First run the retrieval_qa chain on current question
    if first_run:
        current_question = scratchpad['original_question']
        current_answer, current_documents = retrieval_qa( 
            llm = language_model(temperature=0), 
            store = combined_text_store, 
            question = current_question, 
            verbose = verbose)
        scratchpad['answerpad'] += [current_answer]
        first_run = False
    else:
        current_answer, current_documents = retrieval_qa( 
            llm = language_model(temperature=0), 
            store = combined_text_store, 
            question = current_question, 
            verbose = verbose)
        scratchpad['notes'] += [{'question': current_question, 'answer': current_answer}]

    scratchpad['current_documents'] = current_documents
    scratchpad['documents'] += current_documents
    print(
        "\033[36;2m",
        f"\nCurrent Question: {current_question}\n", 
        f"Current Answer: {current_answer} \n",
        "\033[0m\033[0m")

    ## 2. Ask more questions based on current_answer as context
    ## ----
    start_id = (current_iteration-1)*num_questions_per_iteration + 1
    question_creation_chain = QuestionCreationChain.from_llm(
        llm = language_model(temperature=question_creation_temperature), 
        verbose=verbose
        )
    question_creation_response = question_creation_chain.run(
        question=scratchpad['original_question'],
        context="\n".join(list(map(lambda x: x.page_content, scratchpad['current_documents']))),
        unanswered_questions=scratchpad['unanswered_questions'],
        num_questions = num_questions_per_iteration,
        start_id=start_id,
    )
    scratchpad['unanswered_questions'] = {
        **scratchpad['unanswered_questions'], 
        **result2DictOfQuestions(result = question_creation_response)
        }

    if current_question_id:
        scratchpad['answered_questions'] += [scratchpad['unanswered_questions'].pop(current_question_id)]
        # Remove the current question here after generating the new questions so that the 
        # current question is not regenerated. 
       
    print(
        "\033[35;3m",
        "** Unanswered Questions **\n",
        "\n".join(f"'{key}. {value}'" for key, value in scratchpad['unanswered_questions'].items()), 
        "\033[32;5m",
        "\n** Answered Questions **\n",
        "\n".join(scratchpad['answered_questions']),
        "\033[0m\033[0m")
    ### --- ###

    ## 3. Find the most pertinent question to ask next 
    ## ----
    find_next_question = MostPertinentQuestion.from_llm(
        llm = language_model(temperature=question_prioritisation_temperature),
        verbose = verbose
        )
    current_question = find_next_question.run(
        original_question=scratchpad['original_question'],
        unanswered_questions="\n".join(f"'{key}. {value}'," for key, value in scratchpad['unanswered_questions'].items()),
    )

    # print("next q response -->", current_question)
    # Calculate question id so it can be deleted in the next iteration
    current_question_id = current_question.split('.', 1)[0]
    current_question = current_question.split('.', 1)[-1]
    print(
        "\033[93m\033[1m", 
        f"\nNext Question I need to ask: {current_question}\nQuestion Id: {current_question_id}", 
        "\033[0m\033[0m")
    ### --- ###



## ----- The Compiler -----
final_answer= research_compiler(
    llm = language_model(temperature = analyser_temperature, verbose=True),
    question = scratchpad['original_question'], 
    context = scratchpad['notes'], 
    prev_answer = scratchpad['answerpad'],
    verbose = verbose)

print("\033[1;37m" + f"\nFinal Answer: \n {final_answer['text']}\n" + "\033[0m\033[0m")  

## ----- Save the run data -----
## If you do not need this, feel free to comment it out. 
_ = runs_store.add_texts(
    texts=[scratchpad['original_question']], 
    metadatas=[{
        'docs_metadata': [document.metadata for document in scratchpad['documents']], 
        'answer': final_answer['text'], 
        'context': final_answer['context']
        }], 
    ids=[run_id])
# Out:
#  ------  Iteration 1 -------
#
#
# Current Question: why did Mahabharata war happen?
#  Current Answer: The Mahabharata war happened because of a series of events and conflicts between the Pandavas and the Kauravas. The fight began in Dwaraka, with some Yadavas defending the Pandavas and others defending the Kauravas. The quarreling citizens of Dwaraka grabbed sharp reeds from the seashore and destroyed themselves. Satyaki and Kritavarma, who had survived the war, killed each other in that fight.
#
# Meanwhile, King Duryodhana had collected a large army to fight against the Pandavas. Both sides amassed their armies and arsenals, intending to aid either the Pandavas or the Kauravas. This was all part of Lord Krishna's plan to decrease the unnecessary military burden of the world. The battle between the Pandavas and the Kauravas raged furiously.
#
# After the battle, Yudhishthira, the Pandava king, became filled with fear at the thought of Gandhari's wrath. He sent Krishna to comfort her before his own arrival. Yudhishthira was concerned about Gandhari's grief upon hearing of her son's unfair death. He feared that she would bring destruction upon them with her ascetic powers.
#
# In summary, the Mahabharata war happened due to the conflicts between the Pandavas and the Kauravas, the quarrels among the citizens of Dwaraka, and Yudhishthira's fear of Gandhari's wrath.
#
#  ** Unanswered Questions **
#  '1. What were the specific events that led to the fight in Dwaraka between the Yadavas defending the Pandavas and those defending the Kauravas?'
# '2. Can you provide more information about the power of Gandhari's curse and how it played a role in the destruction of the Yadavas?'
# '3. What were the reasons behind Krishna's decision to go to Hastinapura after the battle between the Pandavas and the Kauravas?'
# ** Answered Questions **
#
#
# Next Question I need to ask:  Can you provide more information about the power of Gandhari's curse and how it played a role in the destruction of the Yadavas?
# Question Id: 2
#
#  ------  Iteration 2 -------
#
#
# Current Question:  Can you provide more information about the power of Gandhari's curse and how it played a role in the destruction of the Yadavas?
#  Current Answer: Gandhari's curse had a significant impact on the destruction of the Yadavas. The curse was a result of her grief and anger towards Lord Krishna, whom she blamed for the death of her sons in the battle of Kurukshetra. The curse stated that the Yadu dynasty would be destroyed by fratricide, meaning they would kill each other.
#
# Lord Krishna, who was already contemplating how to remove his family from the earth, was satisfied with this curse. He acknowledged that there was no one in the world who could cause the death of the Yadu heroes except himself. He approved of the curse and considered it as aiding him in accomplishing the task of their demise.
#
# As time passed, a fight broke out in Dwaraka between the Yadavas. Some defended the Pandavas, while others defended the Kauravas. The quarreling citizens of Dwaraka, fearing violence, grabbed sharp-edged reeds from the seashore as weapons. This led to the self-destruction of the Yadavas, as they killed each other in the fight.
#
# The power of Gandhari's curse was evident in the fact that even the heavenly gods and demons were incapable of slaying the Yadu heroes. Only Lord Krishna himself could cause their death. The curse played a role in fulfilling Lord Krishna's contemplation of removing his family from the earth, as the Yadavas ultimately perished by each other's weapons.
#
#  ** Unanswered Questions **
#  '1. What were the specific events that led to the fight in Dwaraka between the Yadavas defending the Pandavas and those defending the Kauravas?'
# '3. What were the reasons behind Krishna's decision to go to Hastinapura after the battle between the Pandavas and the Kauravas?'
# '4. What were the immediate causes of the fight in Dwaraka between the Yadavas supporting the Pandavas and those supporting the Kauravas?'
# '5. How did the reeds from the seashore become deadly weapons in the hands of the quarreling citizens of Dwaraka?'
# '6. Can you provide more details on Krishna's decision to go to Hastinapura after the battle between the Pandavas and the Kauravas?'
# ** Answered Questions **
#  Can you provide more information about the power of Gandhari's curse and how it played a role in the destruction of the Yadavas?
#
# Next Question I need to ask:  What were the immediate causes of the fight in Dwaraka between the Yadavas supporting the Pandavas and those supporting the Kauravas?
# Question Id: 4
#
#  ------  Iteration 3 -------
#
#
# Current Question:  What were the immediate causes of the fight in Dwaraka between the Yadavas supporting the Pandavas and those supporting the Kauravas?
#  Current Answer: The immediate causes of the fight in Dwaraka between the Yadavas supporting the Pandavas and those supporting the Kauravas were the ambush of Abhimanyu by the Kauravas and the deception of Drona by the Pandavas. The context mentions that the Kauravas ambushed Abhimanyu, which implies that they attacked him unexpectedly and possibly with the intention to harm or kill him. On the other hand, the Pandavas deceived Drona, suggesting that they tricked or misled him in some way. These actions by both sides led to an argument between the Yadavas, with some defending the Pandavas and others defending the Kauravas.
#
# The escalating tension and fear of violence prompted Krishna and Balarama to hide all the weapons. However, the quarreling citizens of Dwaraka found reeds from the seashore, which had sharp edges like iron weapons. This led to the Yadavas using these reeds as weapons and ultimately destroying themselves. Satyaki and Kritavarma, who had survived the war, ended up killing each other in the fight.
#
# The power of Gandhari's curse is also mentioned as a contributing factor to the destruction of the Yadavas. However, the immediate causes of the fight in Dwaraka were the ambush of Abhimanyu and the deception of Drona, which sparked the argument and subsequent violence between the Yadavas supporting the Pandavas and those supporting the Kauravas.
#
#  ** Unanswered Questions **
#  '1. What were the specific events that led to the fight in Dwaraka between the Yadavas defending the Pandavas and those defending the Kauravas?'
# '3. What were the reasons behind Krishna's decision to go to Hastinapura after the battle between the Pandavas and the Kauravas?'
# '5. How did the reeds from the seashore become deadly weapons in the hands of the quarreling citizens of Dwaraka?'
# '6. Can you provide more details on Krishna's decision to go to Hastinapura after the battle between the Pandavas and the Kauravas?'
# '7. What were the specific events that led to the battle between the Pandavas and the Kauravas at Kurukshetra?'
# '8. What were the reasons behind Duryodhana's eagerness for war against the Pandavas?'
# '9. How did Gandhari's curse contribute to the destruction of the Yadavas in Dwaraka?'
# ** Answered Questions **
#  Can you provide more information about the power of Gandhari's curse and how it played a role in the destruction of the Yadavas?
# What were the immediate causes of the fight in Dwaraka between the Yadavas supporting the Pandavas and those supporting the Kauravas?
#
# Next Question I need to ask:  What were the specific events that led to the battle between the Pandavas and the Kauravas at Kurukshetra?
# Question Id: 7
#
#  ------  Iteration 4 -------
#
#
# Current Question:  What were the specific events that led to the battle between the Pandavas and the Kauravas at Kurukshetra?
#  Current Answer: Based on the given context, the specific events that led to the battle between the Pandavas and the Kauravas at Kurukshetra can be summarized as follows:
#
# 1. The Pandavas, along with their allies and distinguished generals, prepared to move their armies to Kurukshetra, a holy place of pilgrimage where great sages had performed austerities and sacrifices in the past.
#
# 2. The Pandava army, accompanied by millions of men, headed towards Kurukshetra, appearing like a vast ocean that covered the horizon.
#
# 3. Yudhisthira, the leader of the Pandavas, chose a level and grassy part of the field for their troops to encamp.
#
# 4. Lord Krishna and Arjuna, two prominent figures among the Pandavas, blew their conchshells, creating a thunderous sound that filled the Pandava army with joy.
#
# 5. The Kaurava army, led by the invincible Drona, faced the Pandavas at Kurukshetra.
#
# 6. The battle between the two sides raged furiously, with both armies striking each other.
#
# 7. Dhritarastra, the blind king and father of the Kauravas, inquired about the events of the battle from his advisor Sanjaya.
#
# 8. Dhritarastra specifically asked about the actions of the Kaurava army after the demise of Jayadratha, as Drona, their commander, could not tolerate the violation of his vow.
#
# The given context does not provide further details about the specific events that led to the battle, such as the underlying conflicts or the reasons for the Pandavas and Kauravas engaging in war.
#
#  ** Unanswered Questions **
#  '1. What were the specific events that led to the fight in Dwaraka between the Yadavas defending the Pandavas and those defending the Kauravas?'
# '3. What were the reasons behind Krishna's decision to go to Hastinapura after the battle between the Pandavas and the Kauravas?'
# '5. How did the reeds from the seashore become deadly weapons in the hands of the quarreling citizens of Dwaraka?'
# '6. Can you provide more details on Krishna's decision to go to Hastinapura after the battle between the Pandavas and the Kauravas?'
# '8. What were the reasons behind Duryodhana's eagerness for war against the Pandavas?'
# '9. How did Gandhari's curse contribute to the destruction of the Yadavas in Dwaraka?'
# '10. What were the key factors that led to the initiation of the Mahabharata war between the Pandavas and the Kauravas?'
# '11. Can you provide insights into the role of Jayadratha's demise in the night battle at Kurukshetra and its impact on the Kaurava army?'
# '12. How did the selection of the commander in chief and the preparations made by the heroic generals contribute to the escalation of the Mahabharata war?'
# ** Answered Questions **
#  Can you provide more information about the power of Gandhari's curse and how it played a role in the destruction of the Yadavas?
# What were the immediate causes of the fight in Dwaraka between the Yadavas supporting the Pandavas and those supporting the Kauravas?
# What were the specific events that led to the battle between the Pandavas and the Kauravas at Kurukshetra?
#
# Next Question I need to ask:  What were the key factors that led to the initiation of the Mahabharata war between the Pandavas and the Kauravas?
# Question Id: 10
#
#  ------  Iteration 5 -------
#
#
# Current Question:  What were the key factors that led to the initiation of the Mahabharata war between the Pandavas and the Kauravas?
#  Current Answer: Based on the given context, the key factors that led to the initiation of the Mahabharata war between the Pandavas and the Kauravas can be identified as follows:
#
# 1. The dispute over the rightful succession to the throne: The conflict between the Pandavas and the Kauravas originated from the dispute over who should be the rightful heir to the throne of Hastinapura. The Pandavas, led by Yudhisthira, were the rightful heirs as per their lineage, while the Kauravas, led by Duryodhana, were the sons of Dhritarastra, the blind king.
#
# 2. Jealousy and animosity: Duryodhana's jealousy towards the Pandavas, especially towards their skilled and popular brother Arjuna, fueled the animosity between the two factions. Duryodhana's desire for power and unwillingness to share the kingdom with the Pandavas further escalated the tensions.
#
# 3. Attempts to harm the Pandavas: The Kauravas made several attempts to harm the Pandavas and eliminate them as a threat. These included the infamous episode of the attempted killing of the Pandavas and their mother Kunti by burning their house, and the subsequent plot to kill them in the forest.
#
# 4. Failed negotiations and diplomatic efforts: Various attempts were made to resolve the conflict through negotiations and diplomatic efforts, but they ultimately failed due to the stubbornness and arrogance of Duryodhana and his refusal to give the Pandavas their rightful share of the kingdom.
#
# 5. The influence of external factors: The involvement of other characters, such as Krishna and Balarama, and the curse of Gandhari, played significant roles in shaping the events leading to the war. Krishna's efforts to prevent the war and maintain peace were undermined by the actions of the Kauravas and their allies.
#
# In conclusion, the initiation of the Mahabharata war between the Pandavas and the Kauravas was primarily driven by the dispute over the throne, jealousy, failed negotiations, and external influences.
#
#  ** Unanswered Questions **
#  '1. What were the specific events that led to the fight in Dwaraka between the Yadavas defending the Pandavas and those defending the Kauravas?'
# '3. What were the reasons behind Krishna's decision to go to Hastinapura after the battle between the Pandavas and the Kauravas?'
# '5. How did the reeds from the seashore become deadly weapons in the hands of the quarreling citizens of Dwaraka?'
# '6. Can you provide more details on Krishna's decision to go to Hastinapura after the battle between the Pandavas and the Kauravas?'
# '8. What were the reasons behind Duryodhana's eagerness for war against the Pandavas?'
# '9. How did Gandhari's curse contribute to the destruction of the Yadavas in Dwaraka?'
# '11. Can you provide insights into the role of Jayadratha's demise in the night battle at Kurukshetra and its impact on the Kaurava army?'
# '12. How did the selection of the commander in chief and the preparations made by the heroic generals contribute to the escalation of the Mahabharata war?'
# '13. What were the specific strategies employed by the Pandavas and the Kauravas in the battle formation that led to the tremendous clash of weapons?'
# '14. Can you provide more details on the role of Bhima in the battle, particularly his encounter with the King of the Kulutas?'
# '15. How did the death of Satyaki and Kritavarma in the fight between the Yadavas contribute to the overall outcome of the war?'
# ** Answered Questions **
#  Can you provide more information about the power of Gandhari's curse and how it played a role in the destruction of the Yadavas?
# What were the immediate causes of the fight in Dwaraka between the Yadavas supporting the Pandavas and those supporting the Kauravas?
# What were the specific events that led to the battle between the Pandavas and the Kauravas at Kurukshetra?
# What were the key factors that led to the initiation of the Mahabharata war between the Pandavas and the Kauravas?
#
# Next Question I need to ask:  How did the selection of the commander in chief and the preparations made by the heroic generals contribute to the escalation of the Mahabharata war?
# Question Id: 12
#
#  ------  Iteration 6 -------
#
#
#  ------ Max iterations reached.
#
# Final Answer:
#  The Mahabharata war happened due to a combination of factors and events that unfolded over time. One of the key factors was the dispute over the rightful succession to the throne of Hastinapura. The conflict arose between the Pandavas, led by Yudhishthira, and the Kauravas, led by Duryodhana. The Pandavas believed they were the rightful heirs based on their lineage, while the Kauravas, being the sons of the blind king Dhritarashtra, also claimed their right to the throne.
#
# Jealousy and animosity played a significant role in fueling the tensions between the two factions. Duryodhana's jealousy towards the Pandavas, particularly towards their skilled and popular brother Arjuna, further escalated the animosity. Duryodhana's desire for power and his unwillingness to share the kingdom with the Pandavas added to the growing conflict.
#
# The Kauravas made several attempts to harm the Pandavas and eliminate them as a threat. These attempts included the infamous episode of the attempted killing of the Pandavas and their mother Kunti by burning their house, as well as a subsequent plot to kill them in the forest. These actions by the Kauravas only intensified the enmity between the two sides.
#
# Various negotiations and diplomatic efforts were made to resolve the conflict peacefully, but they ultimately failed due to the stubbornness and arrogance of Duryodhana. Despite the efforts of characters like Krishna and Balarama to prevent the war and maintain peace, the actions of the Kauravas and their allies undermined these attempts.
#
# Additionally, external factors played a significant role in shaping the events leading to the war. One such factor was the curse of Gandhari, the mother of the Kauravas. Gandhari's curse, fueled by her grief and anger towards Lord Krishna, stated that the Yadu dynasty, to which Lord Krishna belonged, would be destroyed by fratricide. This curse had a significant impact on the destruction of the Yadavas, as they ultimately killed each other in a fight that broke out in Dwaraka.
#
# In summary, the Mahabharata war happened due to a combination of factors, including the dispute over the throne, jealousy, failed negotiations, and external influences such as Gandhari's curse. These factors, along with the actions and decisions of the characters involved, led to the initiation of the war between the Pandavas and the Kauravas.
# 2023-09-17 13:34:00,088:INFO - HTTP Request: POST https://doxggeyqopdnxfhseufq.supabase.co/rest/v1/runs "HTTP/1.1 201 Created"
